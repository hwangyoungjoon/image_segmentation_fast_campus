# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist=input_data.read_data_sets("MNIST_data",one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz

# %%
# 파라미터 
learning_rate=0.01
training_epochs=20
batch_size=256
display_step=1
example_show=10

# %%
#네트워크 구조 노드 정의
n_hidden1=300
n_hidden2=150
n_input=784

# %%
x=tf.placeholder(tf.float32,[None,n_input])

# %%
# 오토 인코더 빌드

def build_autoencoder(x):
    # 인코딩 784->300
    w1=tf.Variable(tf.random_normal([n_input,n_hidden1]))
    b1=tf.Variable(tf.random_normal([n_hidden1]))
    L1=tf.nn.sigmoid(tf.matmul(x,w1)+b1)
    #인코딩 300-> 150
    w2=tf.Variable(tf.random_normal([n_hidden1,n_hidden2]))
    b2=tf.Variable(tf.random_normal([n_hidden2]))
    L2=tf.nn.sigmoid(tf.matmul(L1,w2)+b2)
    
    # 디코딩150->300
    w3=tf.Variable(tf.random_normal([n_hidden2,n_hidden1]))
    b3=tf.Variable(tf.random_normal([n_hidden1]))
    L3=tf.nn.sigmoid(tf.matmul(L2,w3)+b3)
    
    w4=tf.Variable(tf.random_normal([n_hidden_1,n_input]))
    b4=tf.Variable(tf.random_normal([n_input]))
    reconstructed_x=tf.nn.sigmoid(tf.matmul(L3,w4)+b4)
    
    return reconstructed_x

# %%
predicted_y=build_autoencoder(x)
y_true=x  # 타켓 데이터는 인풋과 같다.

# %%
# loss,optimizer
loss=tf.reduce_mean(tf.pow(y_true-predicted_y,2))
optimizer=tf.train.RMSPropOptimizer(learning_rate).minimize(loss)

# %%
# 그래프 실행
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    total_batch=int(mnist.train.num_examples/batch_size)
    
    for epoch in range(training_epochs):
        for i in range(total_batch):
            batch_xs,batch_ys=mnist.train.next_batch(batch_size)
            _,c=sess.run([optimizer,loss],feed_dict={x:batch_xs})
            
            if epoch % display_step ==0:
                print("반복횟수(epoch):", '%04d'% (epoch+1),
                     "손실함수(loss):", "{:.9f}".format(c))
                
                
    print("최적화 완료")
    
    
    reconstucted_result=sess.run(predicted_y,feed_dict={x:mnist.test.images[:example_show]})
    # 원본이미지와 재구성한 이미지 비교
    f,a=plt.subplots(2,10,figsize=(10,2))
    for i in range(example_show):
        a[0][i].imshow(np.reshape(mnist.test.images[i],(28,28)))
        a[1][i].imshow(np.reshape(reconstucted_result[i],(28,28)))
                       
    f.show()
    plt.draw()
    plt.waitforbuttonpress()
# Out:
# 반복횟수(epoch): 0001 손실함수(loss): 0.448225290
# 반복횟수(epoch): 0001 손실함수(loss): 0.447433472
# 반복횟수(epoch): 0001 손실함수(loss): 0.447164118
# 반복횟수(epoch): 0001 손실함수(loss): 0.448675275
# 반복횟수(epoch): 0001 손실함수(loss): 0.447880387
# 반복횟수(epoch): 0001 손실함수(loss): 0.447342813
# 반복횟수(epoch): 0001 손실함수(loss): 0.449525803
# 반복횟수(epoch): 0001 손실함수(loss): 0.449125379
# 반복횟수(epoch): 0001 손실함수(loss): 0.449369729
# 반복횟수(epoch): 0001 손실함수(loss): 0.448597163
# 반복횟수(epoch): 0001 손실함수(loss): 0.447579145
# 반복횟수(epoch): 0001 손실함수(loss): 0.447512418
# 반복횟수(epoch): 0001 손실함수(loss): 0.448887020
# 반복횟수(epoch): 0001 손실함수(loss): 0.447337717
# 반복횟수(epoch): 0001 손실함수(loss): 0.447831303
# 반복횟수(epoch): 0001 손실함수(loss): 0.449484229
# 반복횟수(epoch): 0001 손실함수(loss): 0.447384417
# 반복횟수(epoch): 0001 손실함수(loss): 0.449321330
# 반복횟수(epoch): 0001 손실함수(loss): 0.448374093
# 반복횟수(epoch): 0001 손실함수(loss): 0.448764920
# 반복횟수(epoch): 0001 손실함수(loss): 0.447186410
# 반복횟수(epoch): 0001 손실함수(loss): 0.447606802
# 반복횟수(epoch): 0001 손실함수(loss): 0.447112411
# 반복횟수(epoch): 0001 손실함수(loss): 0.449085772
# 반복횟수(epoch): 0001 손실함수(loss): 0.448096752
# 반복횟수(epoch): 0001 손실함수(loss): 0.448421776
# 반복횟수(epoch): 0001 손실함수(loss): 0.446639240
# 반복횟수(epoch): 0001 손실함수(loss): 0.449053317
# 반복횟수(epoch): 0001 손실함수(loss): 0.447280228
# 반복횟수(epoch): 0001 손실함수(loss): 0.448170245
# 반복횟수(epoch): 0001 손실함수(loss): 0.448500097
# 반복횟수(epoch): 0001 손실함수(loss): 0.447881430
# 반복횟수(epoch): 0001 손실함수(loss): 0.448157459
# 반복횟수(epoch): 0001 손실함수(loss): 0.447366625
# 반복횟수(epoch): 0001 손실함수(loss): 0.446934938
# 반복횟수(epoch): 0001 손실함수(loss): 0.448156089
# 반복횟수(epoch): 0001 손실함수(loss): 0.449080169
# 반복횟수(epoch): 0001 손실함수(loss): 0.447668195
# 반복횟수(epoch): 0001 손실함수(loss): 0.448981225
# 반복횟수(epoch): 0001 손실함수(loss): 0.447960049
# 반복횟수(epoch): 0001 손실함수(loss): 0.449965447
# 반복횟수(epoch): 0001 손실함수(loss): 0.448867798
# 반복횟수(epoch): 0001 손실함수(loss): 0.449002206
# 반복횟수(epoch): 0001 손실함수(loss): 0.447551638
# 반복횟수(epoch): 0001 손실함수(loss): 0.446478993
# 반복횟수(epoch): 0001 손실함수(loss): 0.448296785
# 반복횟수(epoch): 0001 손실함수(loss): 0.447398603
# 반복횟수(epoch): 0001 손실함수(loss): 0.447782159
# 반복횟수(epoch): 0001 손실함수(loss): 0.447668314
# 반복횟수(epoch): 0001 손실함수(loss): 0.446399212
# 반복횟수(epoch): 0001 손실함수(loss): 0.447662354
# 반복횟수(epoch): 0001 손실함수(loss): 0.447238177
# 반복횟수(epoch): 0001 손실함수(loss): 0.446937203
# 반복횟수(epoch): 0001 손실함수(loss): 0.446614414
# 반복횟수(epoch): 0001 손실함수(loss): 0.447680116
# 반복횟수(epoch): 0001 손실함수(loss): 0.447714478
# 반복횟수(epoch): 0001 손실함수(loss): 0.446403354
# 반복횟수(epoch): 0001 손실함수(loss): 0.447880715
# 반복횟수(epoch): 0001 손실함수(loss): 0.446528882
# 반복횟수(epoch): 0001 손실함수(loss): 0.446253538
# 반복횟수(epoch): 0001 손실함수(loss): 0.447699577
# 반복횟수(epoch): 0001 손실함수(loss): 0.446366996
# 반복횟수(epoch): 0001 손실함수(loss): 0.446532905
# 반복횟수(epoch): 0001 손실함수(loss): 0.446299732
# 반복횟수(epoch): 0001 손실함수(loss): 0.446448654
# 반복횟수(epoch): 0001 손실함수(loss): 0.445376456
# 반복횟수(epoch): 0001 손실함수(loss): 0.446109235
# 반복횟수(epoch): 0001 손실함수(loss): 0.446211398
# 반복횟수(epoch): 0001 손실함수(loss): 0.446964771
# 반복횟수(epoch): 0001 손실함수(loss): 0.445856214
# 반복횟수(epoch): 0001 손실함수(loss): 0.446487963
# 반복횟수(epoch): 0001 손실함수(loss): 0.444702864
# 반복횟수(epoch): 0001 손실함수(loss): 0.445990741
# 반복횟수(epoch): 0001 손실함수(loss): 0.444889188
# 반복횟수(epoch): 0001 손실함수(loss): 0.444121927
# 반복횟수(epoch): 0001 손실함수(loss): 0.445943326
# 반복횟수(epoch): 0001 손실함수(loss): 0.446705967
# 반복횟수(epoch): 0001 손실함수(loss): 0.443981171
# 반복횟수(epoch): 0001 손실함수(loss): 0.445310116
# 반복횟수(epoch): 0001 손실함수(loss): 0.444760650
# 반복횟수(epoch): 0001 손실함수(loss): 0.442502439
# 반복횟수(epoch): 0001 손실함수(loss): 0.441948950
# 반복횟수(epoch): 0001 손실함수(loss): 0.443879336
# 반복횟수(epoch): 0001 손실함수(loss): 0.441780567
# 반복횟수(epoch): 0001 손실함수(loss): 0.441880554
# 반복횟수(epoch): 0001 손실함수(loss): 0.443215340
# 반복횟수(epoch): 0001 손실함수(loss): 0.442481697
# 반복횟수(epoch): 0001 손실함수(loss): 0.441793948
# 반복횟수(epoch): 0001 손실함수(loss): 0.441764534
# 반복횟수(epoch): 0001 손실함수(loss): 0.440373600
# 반복횟수(epoch): 0001 손실함수(loss): 0.439352006
# 반복횟수(epoch): 0001 손실함수(loss): 0.438970953
# 반복횟수(epoch): 0001 손실함수(loss): 0.438352466
# 반복횟수(epoch): 0001 손실함수(loss): 0.437932372
# 반복횟수(epoch): 0001 손실함수(loss): 0.437402606
# 반복횟수(epoch): 0001 손실함수(loss): 0.437058091
# 반복횟수(epoch): 0001 손실함수(loss): 0.436120093
# 반복횟수(epoch): 0001 손실함수(loss): 0.435890436
# 반복횟수(epoch): 0001 손실함수(loss): 0.435921252
# 반복횟수(epoch): 0001 손실함수(loss): 0.435811877
# 반복횟수(epoch): 0001 손실함수(loss): 0.434346557
# 반복횟수(epoch): 0001 손실함수(loss): 0.432859570
# 반복횟수(epoch): 0001 손실함수(loss): 0.432919085
# 반복횟수(epoch): 0001 손실함수(loss): 0.431264281
# 반복횟수(epoch): 0001 손실함수(loss): 0.430417210
# 반복횟수(epoch): 0001 손실함수(loss): 0.430203617
# 반복횟수(epoch): 0001 손실함수(loss): 0.428813428
# 반복횟수(epoch): 0001 손실함수(loss): 0.428706735
# 반복횟수(epoch): 0001 손실함수(loss): 0.427407414
# 반복횟수(epoch): 0001 손실함수(loss): 0.425139666
# 반복횟수(epoch): 0001 손실함수(loss): 0.426505566
# 반복횟수(epoch): 0001 손실함수(loss): 0.423194528
# 반복횟수(epoch): 0001 손실함수(loss): 0.422887176
# 반복횟수(epoch): 0001 손실함수(loss): 0.421697825
# 반복횟수(epoch): 0001 손실함수(loss): 0.419120252
# 반복횟수(epoch): 0001 손실함수(loss): 0.416828930
# 반복횟수(epoch): 0001 손실함수(loss): 0.416251361
# 반복횟수(epoch): 0001 손실함수(loss): 0.415062577
# 반복횟수(epoch): 0001 손실함수(loss): 0.412673712
# 반복횟수(epoch): 0001 손실함수(loss): 0.411884785
# 반복횟수(epoch): 0001 손실함수(loss): 0.408633381
# 반복횟수(epoch): 0001 손실함수(loss): 0.408045083
# 반복횟수(epoch): 0001 손실함수(loss): 0.404809743
# 반복횟수(epoch): 0001 손실함수(loss): 0.403611094
# 반복횟수(epoch): 0001 손실함수(loss): 0.400410444
# 반복횟수(epoch): 0001 손실함수(loss): 0.398799479
# 반복횟수(epoch): 0001 손실함수(loss): 0.394548714
# 반복횟수(epoch): 0001 손실함수(loss): 0.393322587
# 반복횟수(epoch): 0001 손실함수(loss): 0.389424086
# 반복횟수(epoch): 0001 손실함수(loss): 0.387256622
# 반복횟수(epoch): 0001 손실함수(loss): 0.384414971
# 반복횟수(epoch): 0001 손실함수(loss): 0.379546523
# 반복횟수(epoch): 0001 손실함수(loss): 0.377021134
# 반복횟수(epoch): 0001 손실함수(loss): 0.373804957
# 반복횟수(epoch): 0001 손실함수(loss): 0.370237470
# 반복횟수(epoch): 0001 손실함수(loss): 0.367510587
# 반복횟수(epoch): 0001 손실함수(loss): 0.363957316
# 반복횟수(epoch): 0001 손실함수(loss): 0.358472943
# 반복횟수(epoch): 0001 손실함수(loss): 0.356754720
# 반복횟수(epoch): 0001 손실함수(loss): 0.352679282
# 반복횟수(epoch): 0001 손실함수(loss): 0.345987588
# 반복횟수(epoch): 0001 손실함수(loss): 0.341546983
# 반복횟수(epoch): 0001 손실함수(loss): 0.336399734
# 반복횟수(epoch): 0001 손실함수(loss): 0.332556665
# 반복횟수(epoch): 0001 손실함수(loss): 0.327088654
# 반복횟수(epoch): 0001 손실함수(loss): 0.322084248
# 반복횟수(epoch): 0001 손실함수(loss): 0.316153318
# 반복횟수(epoch): 0001 손실함수(loss): 0.310483962
# 반복횟수(epoch): 0001 손실함수(loss): 0.306753367
# 반복횟수(epoch): 0001 손실함수(loss): 0.302116632
# 반복횟수(epoch): 0001 손실함수(loss): 0.296304196
# 반복횟수(epoch): 0001 손실함수(loss): 0.293854415
# 반복횟수(epoch): 0001 손실함수(loss): 0.287875980
# 반복횟수(epoch): 0001 손실함수(loss): 0.283981800
# 반복횟수(epoch): 0001 손실함수(loss): 0.280042499
# 반복횟수(epoch): 0001 손실함수(loss): 0.274860680
# 반복횟수(epoch): 0001 손실함수(loss): 0.271236509
# 반복횟수(epoch): 0001 손실함수(loss): 0.267126620
# 반복횟수(epoch): 0001 손실함수(loss): 0.263542354
# 반복횟수(epoch): 0001 손실함수(loss): 0.259423554
# 반복횟수(epoch): 0001 손실함수(loss): 0.255104452
# 반복횟수(epoch): 0001 손실함수(loss): 0.252500564
# 반복횟수(epoch): 0001 손실함수(loss): 0.250729650
# 반복횟수(epoch): 0001 손실함수(loss): 0.250631273
# 반복횟수(epoch): 0001 손실함수(loss): 0.245528355
# 반복횟수(epoch): 0001 손실함수(loss): 0.241097823
# 반복횟수(epoch): 0001 손실함수(loss): 0.239637300
# 반복횟수(epoch): 0001 손실함수(loss): 0.238983348
# 반복횟수(epoch): 0001 손실함수(loss): 0.235108361
# 반복횟수(epoch): 0001 손실함수(loss): 0.233178139
# 반복횟수(epoch): 0001 손실함수(loss): 0.232529238
# 반복횟수(epoch): 0001 손실함수(loss): 0.230282068
# 반복횟수(epoch): 0001 손실함수(loss): 0.230127230
# 반복횟수(epoch): 0001 손실함수(loss): 0.227226436
# 반복횟수(epoch): 0001 손실함수(loss): 0.229456708
# 반복횟수(epoch): 0001 손실함수(loss): 0.226380989
# 반복횟수(epoch): 0001 손실함수(loss): 0.222651467
# 반복횟수(epoch): 0001 손실함수(loss): 0.221735358
# 반복횟수(epoch): 0001 손실함수(loss): 0.224140570
# 반복횟수(epoch): 0001 손실함수(loss): 0.220723718
# 반복횟수(epoch): 0001 손실함수(loss): 0.220732942
# 반복횟수(epoch): 0001 손실함수(loss): 0.219213381
# 반복횟수(epoch): 0001 손실함수(loss): 0.217818305
# 반복횟수(epoch): 0001 손실함수(loss): 0.218547747
# 반복횟수(epoch): 0001 손실함수(loss): 0.215774968
# 반복횟수(epoch): 0001 손실함수(loss): 0.217849612
# 반복횟수(epoch): 0001 손실함수(loss): 0.216910675
# 반복횟수(epoch): 0001 손실함수(loss): 0.215764940
# 반복횟수(epoch): 0001 손실함수(loss): 0.217468068
# 반복횟수(epoch): 0001 손실함수(loss): 0.216819525
# 반복횟수(epoch): 0001 손실함수(loss): 0.215603888
# 반복횟수(epoch): 0001 손실함수(loss): 0.216058180
# 반복횟수(epoch): 0001 손실함수(loss): 0.215207592
# 반복횟수(epoch): 0001 손실함수(loss): 0.212561980
# 반복횟수(epoch): 0001 손실함수(loss): 0.213420793
# 반복횟수(epoch): 0001 손실함수(loss): 0.212774202
# 반복횟수(epoch): 0001 손실함수(loss): 0.210496277
# 반복횟수(epoch): 0001 손실함수(loss): 0.215379536
# 반복횟수(epoch): 0001 손실함수(loss): 0.212749094
# 반복횟수(epoch): 0001 손실함수(loss): 0.212813050
# 반복횟수(epoch): 0001 손실함수(loss): 0.210500643
# 반복횟수(epoch): 0001 손실함수(loss): 0.211365491
# 반복횟수(epoch): 0001 손실함수(loss): 0.212853611
# 반복횟수(epoch): 0001 손실함수(loss): 0.211025313
# 반복횟수(epoch): 0001 손실함수(loss): 0.212202877
# 반복횟수(epoch): 0001 손실함수(loss): 0.209759980
# 반복횟수(epoch): 0001 손실함수(loss): 0.210019484
# 반복횟수(epoch): 0001 손실함수(loss): 0.209490836
# 반복횟수(epoch): 0001 손실함수(loss): 0.208101124
# 반복횟수(epoch): 0001 손실함수(loss): 0.206207156
# 반복횟수(epoch): 0001 손실함수(loss): 0.206963941
# 반복횟수(epoch): 0001 손실함수(loss): 0.207035780
# 반복횟수(epoch): 0001 손실함수(loss): 0.205902740
# 반복횟수(epoch): 0001 손실함수(loss): 0.204155669
# 반복횟수(epoch): 0002 손실함수(loss): 0.208380699
# 반복횟수(epoch): 0002 손실함수(loss): 0.205471307
# 반복횟수(epoch): 0002 손실함수(loss): 0.206981465
# 반복횟수(epoch): 0002 손실함수(loss): 0.206668675
# 반복횟수(epoch): 0002 손실함수(loss): 0.204310164
# 반복횟수(epoch): 0002 손실함수(loss): 0.205670565
# 반복횟수(epoch): 0002 손실함수(loss): 0.202954799
# 반복횟수(epoch): 0002 손실함수(loss): 0.204280227
# 반복횟수(epoch): 0002 손실함수(loss): 0.201848432
# 반복횟수(epoch): 0002 손실함수(loss): 0.204462290
# 반복횟수(epoch): 0002 손실함수(loss): 0.204235882
# 반복횟수(epoch): 0002 손실함수(loss): 0.203350216
# 반복횟수(epoch): 0002 손실함수(loss): 0.205319077
# 반복횟수(epoch): 0002 손실함수(loss): 0.201774657
# 반복횟수(epoch): 0002 손실함수(loss): 0.202913523
# 반복횟수(epoch): 0002 손실함수(loss): 0.201964781
# 반복횟수(epoch): 0002 손실함수(loss): 0.205267340
# 반복횟수(epoch): 0002 손실함수(loss): 0.202866867
# 반복횟수(epoch): 0002 손실함수(loss): 0.201957703
# 반복횟수(epoch): 0002 손실함수(loss): 0.201559216
# 반복횟수(epoch): 0002 손실함수(loss): 0.203387260
# 반복횟수(epoch): 0002 손실함수(loss): 0.201080114
# 반복횟수(epoch): 0002 손실함수(loss): 0.203110129
# 반복횟수(epoch): 0002 손실함수(loss): 0.201334238
# 반복횟수(epoch): 0002 손실함수(loss): 0.203574628
# 반복횟수(epoch): 0002 손실함수(loss): 0.202513561
# 반복횟수(epoch): 0002 손실함수(loss): 0.199229240
# 반복횟수(epoch): 0002 손실함수(loss): 0.203451648
# 반복횟수(epoch): 0002 손실함수(loss): 0.201205358
# 반복횟수(epoch): 0002 손실함수(loss): 0.198938414
# 반복횟수(epoch): 0002 손실함수(loss): 0.204095244
# 반복횟수(epoch): 0002 손실함수(loss): 0.203952298
# 반복횟수(epoch): 0002 손실함수(loss): 0.202802733
# 반복횟수(epoch): 0002 손실함수(loss): 0.202430770
# 반복횟수(epoch): 0002 손실함수(loss): 0.199609309
# 반복횟수(epoch): 0002 손실함수(loss): 0.201631874
# 반복횟수(epoch): 0002 손실함수(loss): 0.203248516
# 반복횟수(epoch): 0002 손실함수(loss): 0.200393438
# 반복횟수(epoch): 0002 손실함수(loss): 0.202038124
# 반복횟수(epoch): 0002 손실함수(loss): 0.199902996
# 반복횟수(epoch): 0002 손실함수(loss): 0.199400410
# 반복횟수(epoch): 0002 손실함수(loss): 0.200508699
# 반복횟수(epoch): 0002 손실함수(loss): 0.200807318
# 반복횟수(epoch): 0002 손실함수(loss): 0.201689795
# 반복횟수(epoch): 0002 손실함수(loss): 0.199107617
# 반복횟수(epoch): 0002 손실함수(loss): 0.201156214
# 반복횟수(epoch): 0002 손실함수(loss): 0.200321093
# 반복횟수(epoch): 0002 손실함수(loss): 0.203586221
# 반복횟수(epoch): 0002 손실함수(loss): 0.202487618
# 반복횟수(epoch): 0002 손실함수(loss): 0.201929837
# 반복횟수(epoch): 0002 손실함수(loss): 0.201169908
# 반복횟수(epoch): 0002 손실함수(loss): 0.201540038
# 반복횟수(epoch): 0002 손실함수(loss): 0.202260777
# 반복횟수(epoch): 0002 손실함수(loss): 0.201889917
# 반복횟수(epoch): 0002 손실함수(loss): 0.197758630
# 반복횟수(epoch): 0002 손실함수(loss): 0.199425206
# 반복횟수(epoch): 0002 손실함수(loss): 0.198591381
# 반복횟수(epoch): 0002 손실함수(loss): 0.199899524
# 반복횟수(epoch): 0002 손실함수(loss): 0.198936254
# 반복횟수(epoch): 0002 손실함수(loss): 0.199731246
# 반복횟수(epoch): 0002 손실함수(loss): 0.200356111
# 반복횟수(epoch): 0002 손실함수(loss): 0.199235678
# 반복횟수(epoch): 0002 손실함수(loss): 0.200356215
# 반복횟수(epoch): 0002 손실함수(loss): 0.199899986
# 반복횟수(epoch): 0002 손실함수(loss): 0.199420780
# 반복횟수(epoch): 0002 손실함수(loss): 0.198981211
# 반복횟수(epoch): 0002 손실함수(loss): 0.201508075
# 반복횟수(epoch): 0002 손실함수(loss): 0.197252035
# 반복횟수(epoch): 0002 손실함수(loss): 0.199373648
# 반복횟수(epoch): 0002 손실함수(loss): 0.199457064
# 반복횟수(epoch): 0002 손실함수(loss): 0.197766811
# 반복횟수(epoch): 0002 손실함수(loss): 0.199467286
# 반복횟수(epoch): 0002 손실함수(loss): 0.199285626
# 반복횟수(epoch): 0002 손실함수(loss): 0.199498981
# 반복횟수(epoch): 0002 손실함수(loss): 0.198061615
# 반복횟수(epoch): 0002 손실함수(loss): 0.199122027
# 반복횟수(epoch): 0002 손실함수(loss): 0.197786584
# 반복횟수(epoch): 0002 손실함수(loss): 0.199017853
# 반복횟수(epoch): 0002 손실함수(loss): 0.199362069
# 반복횟수(epoch): 0002 손실함수(loss): 0.199289083
# 반복횟수(epoch): 0002 손실함수(loss): 0.197695553
# 반복횟수(epoch): 0002 손실함수(loss): 0.200187609
# 반복횟수(epoch): 0002 손실함수(loss): 0.201408178
# 반복횟수(epoch): 0002 손실함수(loss): 0.199625507
# 반복횟수(epoch): 0002 손실함수(loss): 0.199622452
# 반복횟수(epoch): 0002 손실함수(loss): 0.199086502
# 반복횟수(epoch): 0002 손실함수(loss): 0.199226961
# 반복횟수(epoch): 0002 손실함수(loss): 0.199188665
# 반복횟수(epoch): 0002 손실함수(loss): 0.197051167
# 반복횟수(epoch): 0002 손실함수(loss): 0.196996495
# 반복횟수(epoch): 0002 손실함수(loss): 0.199576825
# 반복횟수(epoch): 0002 손실함수(loss): 0.196820661
# 반복횟수(epoch): 0002 손실함수(loss): 0.198608205
# 반복횟수(epoch): 0002 손실함수(loss): 0.199682057
# 반복횟수(epoch): 0002 손실함수(loss): 0.196843550
# 반복횟수(epoch): 0002 손실함수(loss): 0.198434591
# 반복횟수(epoch): 0002 손실함수(loss): 0.198156238
# 반복횟수(epoch): 0002 손실함수(loss): 0.195481122
# 반복횟수(epoch): 0002 손실함수(loss): 0.201643229
# 반복횟수(epoch): 0002 손실함수(loss): 0.198585391
# 반복횟수(epoch): 0002 손실함수(loss): 0.198738307
# 반복횟수(epoch): 0002 손실함수(loss): 0.195231378
# 반복횟수(epoch): 0002 손실함수(loss): 0.198030084
# 반복횟수(epoch): 0002 손실함수(loss): 0.196909338
# 반복횟수(epoch): 0002 손실함수(loss): 0.198870614
# 반복횟수(epoch): 0002 손실함수(loss): 0.198196858
# 반복횟수(epoch): 0002 손실함수(loss): 0.197112575
# 반복횟수(epoch): 0002 손실함수(loss): 0.198113769
# 반복횟수(epoch): 0002 손실함수(loss): 0.197607562
# 반복횟수(epoch): 0002 손실함수(loss): 0.198890373
# 반복횟수(epoch): 0002 손실함수(loss): 0.197906420
# 반복횟수(epoch): 0002 손실함수(loss): 0.197159246
# 반복횟수(epoch): 0002 손실함수(loss): 0.195020407
# 반복횟수(epoch): 0002 손실함수(loss): 0.199201196
# 반복횟수(epoch): 0002 손실함수(loss): 0.193710566
# 반복횟수(epoch): 0002 손실함수(loss): 0.196562245
# 반복횟수(epoch): 0002 손실함수(loss): 0.195782468
# 반복횟수(epoch): 0002 손실함수(loss): 0.194718227
# 반복횟수(epoch): 0002 손실함수(loss): 0.196271971
# 반복횟수(epoch): 0002 손실함수(loss): 0.192325860
# 반복횟수(epoch): 0002 손실함수(loss): 0.193351597
# 반복횟수(epoch): 0002 손실함수(loss): 0.192976043
# 반복횟수(epoch): 0002 손실함수(loss): 0.197342023
# 반복횟수(epoch): 0002 손실함수(loss): 0.192461327
# 반복횟수(epoch): 0002 손실함수(loss): 0.195905119
# 반복횟수(epoch): 0002 손실함수(loss): 0.193300262
# 반복횟수(epoch): 0002 손실함수(loss): 0.191447750
# 반복횟수(epoch): 0002 손실함수(loss): 0.190076515
# 반복횟수(epoch): 0002 손실함수(loss): 0.191845089
# 반복횟수(epoch): 0002 손실함수(loss): 0.191133097
# 반복횟수(epoch): 0002 손실함수(loss): 0.193412676
# 반복횟수(epoch): 0002 손실함수(loss): 0.191747531
# 반복횟수(epoch): 0002 손실함수(loss): 0.192597091
# 반복횟수(epoch): 0002 손실함수(loss): 0.192286849
# 반복횟수(epoch): 0002 손실함수(loss): 0.195364818
# 반복횟수(epoch): 0002 손실함수(loss): 0.194466323
# 반복횟수(epoch): 0002 손실함수(loss): 0.192496866
# 반복횟수(epoch): 0002 손실함수(loss): 0.194209665
# 반복횟수(epoch): 0002 손실함수(loss): 0.191367254
# 반복횟수(epoch): 0002 손실함수(loss): 0.190936342
# 반복횟수(epoch): 0002 손실함수(loss): 0.190597534
# 반복횟수(epoch): 0002 손실함수(loss): 0.192976564
# 반복횟수(epoch): 0002 손실함수(loss): 0.193910092
# 반복횟수(epoch): 0002 손실함수(loss): 0.196201429
# 반복횟수(epoch): 0002 손실함수(loss): 0.193018794
# 반복횟수(epoch): 0002 손실함수(loss): 0.191941768
# 반복횟수(epoch): 0002 손실함수(loss): 0.194300786
# 반복횟수(epoch): 0002 손실함수(loss): 0.193980962
# 반복횟수(epoch): 0002 손실함수(loss): 0.192678124
# 반복횟수(epoch): 0002 손실함수(loss): 0.191410765
# 반복횟수(epoch): 0002 손실함수(loss): 0.190254793
# 반복횟수(epoch): 0002 손실함수(loss): 0.194285572
# 반복횟수(epoch): 0002 손실함수(loss): 0.191920862
# 반복횟수(epoch): 0002 손실함수(loss): 0.189692125
# 반복횟수(epoch): 0002 손실함수(loss): 0.194191217
# 반복횟수(epoch): 0002 손실함수(loss): 0.191268176
# 반복횟수(epoch): 0002 손실함수(loss): 0.191361547
# 반복횟수(epoch): 0002 손실함수(loss): 0.193287328
# 반복횟수(epoch): 0002 손실함수(loss): 0.192505449
# 반복횟수(epoch): 0002 손실함수(loss): 0.190426692
# 반복횟수(epoch): 0002 손실함수(loss): 0.192155838
# 반복횟수(epoch): 0002 손실함수(loss): 0.190640345
# 반복횟수(epoch): 0002 손실함수(loss): 0.193285450
# 반복횟수(epoch): 0002 손실함수(loss): 0.191823512
# 반복횟수(epoch): 0002 손실함수(loss): 0.194087327
# 반복횟수(epoch): 0002 손실함수(loss): 0.188434243
# 반복횟수(epoch): 0002 손실함수(loss): 0.190288171
# 반복횟수(epoch): 0002 손실함수(loss): 0.189978793
# 반복횟수(epoch): 0002 손실함수(loss): 0.189321145
# 반복횟수(epoch): 0002 손실함수(loss): 0.189798206
# 반복횟수(epoch): 0002 손실함수(loss): 0.191736653
# 반복횟수(epoch): 0002 손실함수(loss): 0.188005596
# 반복횟수(epoch): 0002 손실함수(loss): 0.189415559
# 반복횟수(epoch): 0002 손실함수(loss): 0.189141795
# 반복횟수(epoch): 0002 손실함수(loss): 0.189802378
# 반복횟수(epoch): 0002 손실함수(loss): 0.190646380
# 반복횟수(epoch): 0002 손실함수(loss): 0.188352719
# 반복횟수(epoch): 0002 손실함수(loss): 0.190871298
# 반복횟수(epoch): 0002 손실함수(loss): 0.188591361
# 반복횟수(epoch): 0002 손실함수(loss): 0.186630368
# 반복횟수(epoch): 0002 손실함수(loss): 0.186885267
# 반복횟수(epoch): 0002 손실함수(loss): 0.187271670
# 반복횟수(epoch): 0002 손실함수(loss): 0.186978236
# 반복횟수(epoch): 0002 손실함수(loss): 0.187843189
# 반복횟수(epoch): 0002 손실함수(loss): 0.188271776
# 반복횟수(epoch): 0002 손실함수(loss): 0.186387882
# 반복횟수(epoch): 0002 손실함수(loss): 0.187922224
# 반복횟수(epoch): 0002 손실함수(loss): 0.187936708
# 반복횟수(epoch): 0002 손실함수(loss): 0.189607292
# 반복횟수(epoch): 0002 손실함수(loss): 0.187415883
# 반복횟수(epoch): 0002 손실함수(loss): 0.186563030
# 반복횟수(epoch): 0002 손실함수(loss): 0.189930230
# 반복횟수(epoch): 0002 손실함수(loss): 0.187331021
# 반복횟수(epoch): 0002 손실함수(loss): 0.187537655
# 반복횟수(epoch): 0002 손실함수(loss): 0.185646966
# 반복횟수(epoch): 0002 손실함수(loss): 0.185981944
# 반복횟수(epoch): 0002 손실함수(loss): 0.186290145
# 반복횟수(epoch): 0002 손실함수(loss): 0.187465489
# 반복횟수(epoch): 0002 손실함수(loss): 0.188286886
# 반복횟수(epoch): 0002 손실함수(loss): 0.186129078
# 반복횟수(epoch): 0002 손실함수(loss): 0.188288614
# 반복횟수(epoch): 0002 손실함수(loss): 0.188056171
# 반복횟수(epoch): 0002 손실함수(loss): 0.188051239
# 반복횟수(epoch): 0002 손실함수(loss): 0.186212942
# 반복횟수(epoch): 0002 손실함수(loss): 0.184881568
# 반복횟수(epoch): 0002 손실함수(loss): 0.187533394
# 반복횟수(epoch): 0002 손실함수(loss): 0.188136622
# 반복횟수(epoch): 0002 손실함수(loss): 0.186780974
# 반복횟수(epoch): 0002 손실함수(loss): 0.186104089
# 반복횟수(epoch): 0002 손실함수(loss): 0.184689790
# 반복횟수(epoch): 0002 손실함수(loss): 0.185101137
# 반복횟수(epoch): 0002 손실함수(loss): 0.183605939
# 반복횟수(epoch): 0002 손실함수(loss): 0.185329989
# 반복횟수(epoch): 0002 손실함수(loss): 0.183010101
# 반복횟수(epoch): 0003 손실함수(loss): 0.185673773
# 반복횟수(epoch): 0003 손실함수(loss): 0.184237182
# 반복횟수(epoch): 0003 손실함수(loss): 0.184725747
# 반복횟수(epoch): 0003 손실함수(loss): 0.185433328
# 반복횟수(epoch): 0003 손실함수(loss): 0.185511574
# 반복횟수(epoch): 0003 손실함수(loss): 0.185993657
# 반복횟수(epoch): 0003 손실함수(loss): 0.186374009
# 반복횟수(epoch): 0003 손실함수(loss): 0.185693547
# 반복횟수(epoch): 0003 손실함수(loss): 0.184243888
# 반복횟수(epoch): 0003 손실함수(loss): 0.184555680
# 반복횟수(epoch): 0003 손실함수(loss): 0.186639428
# 반복횟수(epoch): 0003 손실함수(loss): 0.184321925
# 반복횟수(epoch): 0003 손실함수(loss): 0.184082165
# 반복횟수(epoch): 0003 손실함수(loss): 0.183373824
# 반복횟수(epoch): 0003 손실함수(loss): 0.182069853
# 반복횟수(epoch): 0003 손실함수(loss): 0.181648999
# 반복횟수(epoch): 0003 손실함수(loss): 0.182355627
# 반복횟수(epoch): 0003 손실함수(loss): 0.184147462
# 반복횟수(epoch): 0003 손실함수(loss): 0.181378663
# 반복횟수(epoch): 0003 손실함수(loss): 0.179516196
# 반복횟수(epoch): 0003 손실함수(loss): 0.181579009
# 반복횟수(epoch): 0003 손실함수(loss): 0.182509676
# 반복횟수(epoch): 0003 손실함수(loss): 0.183278933
# 반복횟수(epoch): 0003 손실함수(loss): 0.182384565
# 반복횟수(epoch): 0003 손실함수(loss): 0.185098141
# 반복횟수(epoch): 0003 손실함수(loss): 0.183138043
# 반복횟수(epoch): 0003 손실함수(loss): 0.181294262
# 반복횟수(epoch): 0003 손실함수(loss): 0.180034399
# 반복횟수(epoch): 0003 손실함수(loss): 0.183490127
# 반복횟수(epoch): 0003 손실함수(loss): 0.182942018
# 반복횟수(epoch): 0003 손실함수(loss): 0.181387380
# 반복횟수(epoch): 0003 손실함수(loss): 0.180229902
# 반복횟수(epoch): 0003 손실함수(loss): 0.178350434
# 반복횟수(epoch): 0003 손실함수(loss): 0.178473547
# 반복횟수(epoch): 0003 손실함수(loss): 0.179240793
# 반복횟수(epoch): 0003 손실함수(loss): 0.180554703
# 반복횟수(epoch): 0003 손실함수(loss): 0.177347109
# 반복횟수(epoch): 0003 손실함수(loss): 0.179258168
# 반복횟수(epoch): 0003 손실함수(loss): 0.179809585
# 반복횟수(epoch): 0003 손실함수(loss): 0.178315029
# 반복횟수(epoch): 0003 손실함수(loss): 0.177118570
# 반복횟수(epoch): 0003 손실함수(loss): 0.177712694
# 반복횟수(epoch): 0003 손실함수(loss): 0.178758666
# 반복횟수(epoch): 0003 손실함수(loss): 0.177286550
# 반복횟수(epoch): 0003 손실함수(loss): 0.177560851
# 반복횟수(epoch): 0003 손실함수(loss): 0.176162094
# 반복횟수(epoch): 0003 손실함수(loss): 0.176391095
# 반복횟수(epoch): 0003 손실함수(loss): 0.175641105
# 반복횟수(epoch): 0003 손실함수(loss): 0.176546171
# 반복횟수(epoch): 0003 손실함수(loss): 0.176560417
# 반복횟수(epoch): 0003 손실함수(loss): 0.178655326
# 반복횟수(epoch): 0003 손실함수(loss): 0.176484749
# 반복횟수(epoch): 0003 손실함수(loss): 0.177714288
# 반복횟수(epoch): 0003 손실함수(loss): 0.176314846
# 반복횟수(epoch): 0003 손실함수(loss): 0.175612465
# 반복횟수(epoch): 0003 손실함수(loss): 0.176183581
# 반복횟수(epoch): 0003 손실함수(loss): 0.176937610
# 반복횟수(epoch): 0003 손실함수(loss): 0.176668867
# 반복횟수(epoch): 0003 손실함수(loss): 0.177246362
# 반복횟수(epoch): 0003 손실함수(loss): 0.177391008
# 반복횟수(epoch): 0003 손실함수(loss): 0.178459629
# 반복횟수(epoch): 0003 손실함수(loss): 0.178156525
# 반복횟수(epoch): 0003 손실함수(loss): 0.177260250
# 반복횟수(epoch): 0003 손실함수(loss): 0.175854668
# 반복횟수(epoch): 0003 손실함수(loss): 0.175150126
# 반복횟수(epoch): 0003 손실함수(loss): 0.175284535
# 반복횟수(epoch): 0003 손실함수(loss): 0.176452011
# 반복횟수(epoch): 0003 손실함수(loss): 0.177752435
# 반복횟수(epoch): 0003 손실함수(loss): 0.176729247
# 반복횟수(epoch): 0003 손실함수(loss): 0.177251860
# 반복횟수(epoch): 0003 손실함수(loss): 0.176755980
# 반복횟수(epoch): 0003 손실함수(loss): 0.173877448
# 반복횟수(epoch): 0003 손실함수(loss): 0.173968643
# 반복횟수(epoch): 0003 손실함수(loss): 0.176278755
# 반복횟수(epoch): 0003 손실함수(loss): 0.175365448
# 반복횟수(epoch): 0003 손실함수(loss): 0.175614730
# 반복횟수(epoch): 0003 손실함수(loss): 0.175700679
# 반복횟수(epoch): 0003 손실함수(loss): 0.177506119
# 반복횟수(epoch): 0003 손실함수(loss): 0.176589534
# 반복횟수(epoch): 0003 손실함수(loss): 0.175503045
# 반복횟수(epoch): 0003 손실함수(loss): 0.175901264
# 반복횟수(epoch): 0003 손실함수(loss): 0.175147876
# 반복횟수(epoch): 0003 손실함수(loss): 0.175603300
# 반복횟수(epoch): 0003 손실함수(loss): 0.179083169
# 반복횟수(epoch): 0003 손실함수(loss): 0.172460750
# 반복횟수(epoch): 0003 손실함수(loss): 0.178376719
# 반복횟수(epoch): 0003 손실함수(loss): 0.173610285
# 반복횟수(epoch): 0003 손실함수(loss): 0.174881831
# 반복횟수(epoch): 0003 손실함수(loss): 0.175267324
# 반복횟수(epoch): 0003 손실함수(loss): 0.174672619
# 반복횟수(epoch): 0003 손실함수(loss): 0.173973665
# 반복횟수(epoch): 0003 손실함수(loss): 0.176608190
# 반복횟수(epoch): 0003 손실함수(loss): 0.174857035
# 반복횟수(epoch): 0003 손실함수(loss): 0.175341621
# 반복횟수(epoch): 0003 손실함수(loss): 0.172809780
# 반복횟수(epoch): 0003 손실함수(loss): 0.173872933
# 반복횟수(epoch): 0003 손실함수(loss): 0.174907044
# 반복횟수(epoch): 0003 손실함수(loss): 0.177660495
# 반복횟수(epoch): 0003 손실함수(loss): 0.174192160
# 반복횟수(epoch): 0003 손실함수(loss): 0.176223353
# 반복횟수(epoch): 0003 손실함수(loss): 0.175672859
# 반복횟수(epoch): 0003 손실함수(loss): 0.175076887
# 반복횟수(epoch): 0003 손실함수(loss): 0.171247125
# 반복횟수(epoch): 0003 손실함수(loss): 0.174221337
# 반복횟수(epoch): 0003 손실함수(loss): 0.172964558
# 반복횟수(epoch): 0003 손실함수(loss): 0.174956143
# 반복횟수(epoch): 0003 손실함수(loss): 0.174247995
# 반복횟수(epoch): 0003 손실함수(loss): 0.173364505
# 반복횟수(epoch): 0003 손실함수(loss): 0.175255731
# 반복횟수(epoch): 0003 손실함수(loss): 0.172508940
# 반복횟수(epoch): 0003 손실함수(loss): 0.175267324
# 반복횟수(epoch): 0003 손실함수(loss): 0.173643306
# 반복횟수(epoch): 0003 손실함수(loss): 0.177302659
# 반복횟수(epoch): 0003 손실함수(loss): 0.173839837
# 반복횟수(epoch): 0003 손실함수(loss): 0.172712728
# 반복횟수(epoch): 0003 손실함수(loss): 0.170885861
# 반복횟수(epoch): 0003 손실함수(loss): 0.173057929
# 반복횟수(epoch): 0003 손실함수(loss): 0.171873540
# 반복횟수(epoch): 0003 손실함수(loss): 0.172049627
# 반복횟수(epoch): 0003 손실함수(loss): 0.172732815
# 반복횟수(epoch): 0003 손실함수(loss): 0.170499951
# 반복횟수(epoch): 0003 손실함수(loss): 0.171769202
# 반복횟수(epoch): 0003 손실함수(loss): 0.173292235
# 반복횟수(epoch): 0003 손실함수(loss): 0.170716032
# 반복횟수(epoch): 0003 손실함수(loss): 0.172825515
# 반복횟수(epoch): 0003 손실함수(loss): 0.171440065
# 반복횟수(epoch): 0003 손실함수(loss): 0.173305973
# 반복횟수(epoch): 0003 손실함수(loss): 0.171964496
# 반복횟수(epoch): 0003 손실함수(loss): 0.170503363
# 반복횟수(epoch): 0003 손실함수(loss): 0.172305286
# 반복횟수(epoch): 0003 손실함수(loss): 0.171674982
# 반복횟수(epoch): 0003 손실함수(loss): 0.172097608
# 반복횟수(epoch): 0003 손실함수(loss): 0.171782479
# 반복횟수(epoch): 0003 손실함수(loss): 0.170392290
# 반복횟수(epoch): 0003 손실함수(loss): 0.175169185
# 반복횟수(epoch): 0003 손실함수(loss): 0.174516737
# 반복횟수(epoch): 0003 손실함수(loss): 0.177920148
# 반복횟수(epoch): 0003 손실함수(loss): 0.172508165
# 반복횟수(epoch): 0003 손실함수(loss): 0.172616854
# 반복횟수(epoch): 0003 손실함수(loss): 0.172354519
# 반복횟수(epoch): 0003 손실함수(loss): 0.173161879
# 반복횟수(epoch): 0003 손실함수(loss): 0.172554284
# 반복횟수(epoch): 0003 손실함수(loss): 0.171698779
# 반복횟수(epoch): 0003 손실함수(loss): 0.170470536
# 반복횟수(epoch): 0003 손실함수(loss): 0.171565190
# 반복횟수(epoch): 0003 손실함수(loss): 0.171695590
# 반복횟수(epoch): 0003 손실함수(loss): 0.173249543
# 반복횟수(epoch): 0003 손실함수(loss): 0.171039537
# 반복횟수(epoch): 0003 손실함수(loss): 0.171821415
# 반복횟수(epoch): 0003 손실함수(loss): 0.172609985
# 반복횟수(epoch): 0003 손실함수(loss): 0.171290100
# 반복횟수(epoch): 0003 손실함수(loss): 0.170605108
# 반복횟수(epoch): 0003 손실함수(loss): 0.169873223
# 반복횟수(epoch): 0003 손실함수(loss): 0.168786317
# 반복횟수(epoch): 0003 손실함수(loss): 0.169827819
# 반복횟수(epoch): 0003 손실함수(loss): 0.169384494
# 반복횟수(epoch): 0003 손실함수(loss): 0.170044303
# 반복횟수(epoch): 0003 손실함수(loss): 0.168303356
# 반복횟수(epoch): 0003 손실함수(loss): 0.167618155
# 반복횟수(epoch): 0003 손실함수(loss): 0.170710161
# 반복횟수(epoch): 0003 손실함수(loss): 0.171779484
# 반복횟수(epoch): 0003 손실함수(loss): 0.168023854
# 반복횟수(epoch): 0003 손실함수(loss): 0.170130357
# 반복횟수(epoch): 0003 손실함수(loss): 0.170733407
# 반복횟수(epoch): 0003 손실함수(loss): 0.168615073
# 반복횟수(epoch): 0003 손실함수(loss): 0.167933986
# 반복횟수(epoch): 0003 손실함수(loss): 0.171120495
# 반복횟수(epoch): 0003 손실함수(loss): 0.168832347
# 반복횟수(epoch): 0003 손실함수(loss): 0.168877274
# 반복횟수(epoch): 0003 손실함수(loss): 0.168041781
# 반복횟수(epoch): 0003 손실함수(loss): 0.166146532
# 반복횟수(epoch): 0003 손실함수(loss): 0.168944091
# 반복횟수(epoch): 0003 손실함수(loss): 0.168457091
# 반복횟수(epoch): 0003 손실함수(loss): 0.167305946
# 반복횟수(epoch): 0003 손실함수(loss): 0.165224180
# 반복횟수(epoch): 0003 손실함수(loss): 0.167374209
# 반복횟수(epoch): 0003 손실함수(loss): 0.165682912
# 반복횟수(epoch): 0003 손실함수(loss): 0.167851567
# 반복횟수(epoch): 0003 손실함수(loss): 0.168203741
# 반복횟수(epoch): 0003 손실함수(loss): 0.166198790
# 반복횟수(epoch): 0003 손실함수(loss): 0.167490259
# 반복횟수(epoch): 0003 손실함수(loss): 0.167768359
# 반복횟수(epoch): 0003 손실함수(loss): 0.167558655
# 반복횟수(epoch): 0003 손실함수(loss): 0.166136876
# 반복횟수(epoch): 0003 손실함수(loss): 0.165622756
# 반복횟수(epoch): 0003 손실함수(loss): 0.166059136
# 반복횟수(epoch): 0003 손실함수(loss): 0.167739555
# 반복횟수(epoch): 0003 손실함수(loss): 0.168319121
# 반복횟수(epoch): 0003 손실함수(loss): 0.167087063
# 반복횟수(epoch): 0003 손실함수(loss): 0.166264042
# 반복횟수(epoch): 0003 손실함수(loss): 0.164159954
# 반복횟수(epoch): 0003 손실함수(loss): 0.166246727
# 반복횟수(epoch): 0003 손실함수(loss): 0.166916788
# 반복횟수(epoch): 0003 손실함수(loss): 0.162748098
# 반복횟수(epoch): 0003 손실함수(loss): 0.162252188
# 반복횟수(epoch): 0003 손실함수(loss): 0.163740799
# 반복횟수(epoch): 0003 손실함수(loss): 0.164443821
# 반복횟수(epoch): 0003 손실함수(loss): 0.165304258
# 반복횟수(epoch): 0003 손실함수(loss): 0.165425852
# 반복횟수(epoch): 0003 손실함수(loss): 0.166266426
# 반복횟수(epoch): 0003 손실함수(loss): 0.162685320
# 반복횟수(epoch): 0003 손실함수(loss): 0.163799435
# 반복횟수(epoch): 0003 손실함수(loss): 0.163624823
# 반복횟수(epoch): 0003 손실함수(loss): 0.165101320
# 반복횟수(epoch): 0003 손실함수(loss): 0.166224852
# 반복횟수(epoch): 0003 손실함수(loss): 0.164270520
# 반복횟수(epoch): 0003 손실함수(loss): 0.164424464
# 반복횟수(epoch): 0003 손실함수(loss): 0.164107814
# 반복횟수(epoch): 0003 손실함수(loss): 0.162326992
# 반복횟수(epoch): 0003 손실함수(loss): 0.165270045
# 반복횟수(epoch): 0003 손실함수(loss): 0.164418399
# 반복횟수(epoch): 0003 손실함수(loss): 0.165592387
# 반복횟수(epoch): 0003 손실함수(loss): 0.163627580
# 반복횟수(epoch): 0003 손실함수(loss): 0.165035605
# 반복횟수(epoch): 0004 손실함수(loss): 0.163063094
# 반복횟수(epoch): 0004 손실함수(loss): 0.164982691
# 반복횟수(epoch): 0004 손실함수(loss): 0.163467795
# 반복횟수(epoch): 0004 손실함수(loss): 0.164265782
# 반복횟수(epoch): 0004 손실함수(loss): 0.160544470
# 반복횟수(epoch): 0004 손실함수(loss): 0.165467530
# 반복횟수(epoch): 0004 손실함수(loss): 0.161921069
# 반복횟수(epoch): 0004 손실함수(loss): 0.163710281
# 반복횟수(epoch): 0004 손실함수(loss): 0.162897751
# 반복횟수(epoch): 0004 손실함수(loss): 0.164918199
# 반복횟수(epoch): 0004 손실함수(loss): 0.164051577
# 반복횟수(epoch): 0004 손실함수(loss): 0.166912854
# 반복횟수(epoch): 0004 손실함수(loss): 0.164343894
# 반복횟수(epoch): 0004 손실함수(loss): 0.163308784
# 반복횟수(epoch): 0004 손실함수(loss): 0.162681401
# 반복횟수(epoch): 0004 손실함수(loss): 0.163103700
# 반복횟수(epoch): 0004 손실함수(loss): 0.163169742
# 반복횟수(epoch): 0004 손실함수(loss): 0.163353801
# 반복횟수(epoch): 0004 손실함수(loss): 0.163355768
# 반복횟수(epoch): 0004 손실함수(loss): 0.161914751
# 반복횟수(epoch): 0004 손실함수(loss): 0.161302209
# 반복횟수(epoch): 0004 손실함수(loss): 0.161183745
# 반복횟수(epoch): 0004 손실함수(loss): 0.163248718
# 반복횟수(epoch): 0004 손실함수(loss): 0.164587915
# 반복횟수(epoch): 0004 손실함수(loss): 0.162681505
# 반복횟수(epoch): 0004 손실함수(loss): 0.163654909
# 반복횟수(epoch): 0004 손실함수(loss): 0.163804308
# 반복횟수(epoch): 0004 손실함수(loss): 0.161809072
# 반복횟수(epoch): 0004 손실함수(loss): 0.161552310
# 반복횟수(epoch): 0004 손실함수(loss): 0.163391232
# 반복횟수(epoch): 0004 손실함수(loss): 0.161913186
# 반복횟수(epoch): 0004 손실함수(loss): 0.162460506
# 반복횟수(epoch): 0004 손실함수(loss): 0.162274912
# 반복횟수(epoch): 0004 손실함수(loss): 0.162936404
# 반복횟수(epoch): 0004 손실함수(loss): 0.161788374
# 반복횟수(epoch): 0004 손실함수(loss): 0.161151528
# 반복횟수(epoch): 0004 손실함수(loss): 0.162444219
# 반복횟수(epoch): 0004 손실함수(loss): 0.162534088
# 반복횟수(epoch): 0004 손실함수(loss): 0.162187532
# 반복횟수(epoch): 0004 손실함수(loss): 0.162421942
# 반복횟수(epoch): 0004 손실함수(loss): 0.158960640
# 반복횟수(epoch): 0004 손실함수(loss): 0.160468608
# 반복횟수(epoch): 0004 손실함수(loss): 0.160929233
# 반복횟수(epoch): 0004 손실함수(loss): 0.160395622
# 반복횟수(epoch): 0004 손실함수(loss): 0.163004935
# 반복횟수(epoch): 0004 손실함수(loss): 0.162088379
# 반복횟수(epoch): 0004 손실함수(loss): 0.161595047
# 반복횟수(epoch): 0004 손실함수(loss): 0.161270469
# 반복횟수(epoch): 0004 손실함수(loss): 0.159731641
# 반복횟수(epoch): 0004 손실함수(loss): 0.158696741
# 반복횟수(epoch): 0004 손실함수(loss): 0.158151388
# 반복횟수(epoch): 0004 손실함수(loss): 0.160747886
# 반복횟수(epoch): 0004 손실함수(loss): 0.160952583
# 반복횟수(epoch): 0004 손실함수(loss): 0.159244105
# 반복횟수(epoch): 0004 손실함수(loss): 0.160882965
# 반복횟수(epoch): 0004 손실함수(loss): 0.158923432
# 반복횟수(epoch): 0004 손실함수(loss): 0.160598397
# 반복횟수(epoch): 0004 손실함수(loss): 0.157736391
# 반복횟수(epoch): 0004 손실함수(loss): 0.159740463
# 반복횟수(epoch): 0004 손실함수(loss): 0.161750793
# 반복횟수(epoch): 0004 손실함수(loss): 0.162705481
# 반복횟수(epoch): 0004 손실함수(loss): 0.159769639
# 반복횟수(epoch): 0004 손실함수(loss): 0.159101114
# 반복횟수(epoch): 0004 손실함수(loss): 0.160280287
# 반복횟수(epoch): 0004 손실함수(loss): 0.160658538
# 반복횟수(epoch): 0004 손실함수(loss): 0.157277018
# 반복횟수(epoch): 0004 손실함수(loss): 0.158322349
# 반복횟수(epoch): 0004 손실함수(loss): 0.159480408
# 반복횟수(epoch): 0004 손실함수(loss): 0.159403175
# 반복횟수(epoch): 0004 손실함수(loss): 0.160139069
# 반복횟수(epoch): 0004 손실함수(loss): 0.159861013
# 반복횟수(epoch): 0004 손실함수(loss): 0.161032438
# 반복횟수(epoch): 0004 손실함수(loss): 0.159544736
# 반복횟수(epoch): 0004 손실함수(loss): 0.160370246
# 반복횟수(epoch): 0004 손실함수(loss): 0.161665380
# 반복횟수(epoch): 0004 손실함수(loss): 0.162815958
# 반복횟수(epoch): 0004 손실함수(loss): 0.159418255
# 반복횟수(epoch): 0004 손실함수(loss): 0.158806354
# 반복횟수(epoch): 0004 손실함수(loss): 0.158553183
# 반복횟수(epoch): 0004 손실함수(loss): 0.160790563
# 반복횟수(epoch): 0004 손실함수(loss): 0.159756452
# 반복횟수(epoch): 0004 손실함수(loss): 0.158867672
# 반복횟수(epoch): 0004 손실함수(loss): 0.159214780
# 반복횟수(epoch): 0004 손실함수(loss): 0.157202929
# 반복횟수(epoch): 0004 손실함수(loss): 0.157530457
# 반복횟수(epoch): 0004 손실함수(loss): 0.159432530
# 반복횟수(epoch): 0004 손실함수(loss): 0.159060359
# 반복횟수(epoch): 0004 손실함수(loss): 0.158650860
# 반복횟수(epoch): 0004 손실함수(loss): 0.157209411
# 반복횟수(epoch): 0004 손실함수(loss): 0.157916874
# 반복횟수(epoch): 0004 손실함수(loss): 0.156788573
# 반복횟수(epoch): 0004 손실함수(loss): 0.158298358
# 반복횟수(epoch): 0004 손실함수(loss): 0.155573219
# 반복횟수(epoch): 0004 손실함수(loss): 0.157472655
# 반복횟수(epoch): 0004 손실함수(loss): 0.159594104
# 반복횟수(epoch): 0004 손실함수(loss): 0.159185708
# 반복횟수(epoch): 0004 손실함수(loss): 0.159484848
# 반복횟수(epoch): 0004 손실함수(loss): 0.158276483
# 반복횟수(epoch): 0004 손실함수(loss): 0.159343898
# 반복횟수(epoch): 0004 손실함수(loss): 0.159956470
# 반복횟수(epoch): 0004 손실함수(loss): 0.159857973
# 반복횟수(epoch): 0004 손실함수(loss): 0.157764956
# 반복횟수(epoch): 0004 손실함수(loss): 0.159747526
# 반복횟수(epoch): 0004 손실함수(loss): 0.160939083
# 반복횟수(epoch): 0004 손실함수(loss): 0.159700915
# 반복횟수(epoch): 0004 손실함수(loss): 0.156188458
# 반복횟수(epoch): 0004 손실함수(loss): 0.158363327
# 반복횟수(epoch): 0004 손실함수(loss): 0.158647016
# 반복횟수(epoch): 0004 손실함수(loss): 0.157743707
# 반복횟수(epoch): 0004 손실함수(loss): 0.159059227
# 반복횟수(epoch): 0004 손실함수(loss): 0.159598589
# 반복횟수(epoch): 0004 손실함수(loss): 0.155274570
# 반복횟수(epoch): 0004 손실함수(loss): 0.155287251
# 반복횟수(epoch): 0004 손실함수(loss): 0.157861084
# 반복횟수(epoch): 0004 손실함수(loss): 0.159120411
# 반복횟수(epoch): 0004 손실함수(loss): 0.160841033
# 반복횟수(epoch): 0004 손실함수(loss): 0.159512907
# 반복횟수(epoch): 0004 손실함수(loss): 0.159490719
# 반복횟수(epoch): 0004 손실함수(loss): 0.156076759
# 반복횟수(epoch): 0004 손실함수(loss): 0.158772394
# 반복횟수(epoch): 0004 손실함수(loss): 0.157777905
# 반복횟수(epoch): 0004 손실함수(loss): 0.158110768
# 반복횟수(epoch): 0004 손실함수(loss): 0.157050088
# 반복횟수(epoch): 0004 손실함수(loss): 0.158152089
# 반복횟수(epoch): 0004 손실함수(loss): 0.159000054
# 반복횟수(epoch): 0004 손실함수(loss): 0.156997114
# 반복횟수(epoch): 0004 손실함수(loss): 0.155934930
# 반복횟수(epoch): 0004 손실함수(loss): 0.157606766
# 반복횟수(epoch): 0004 손실함수(loss): 0.155580074
# 반복횟수(epoch): 0004 손실함수(loss): 0.156952903
# 반복횟수(epoch): 0004 손실함수(loss): 0.158355311
# 반복횟수(epoch): 0004 손실함수(loss): 0.157933220
# 반복횟수(epoch): 0004 손실함수(loss): 0.157689869
# 반복횟수(epoch): 0004 손실함수(loss): 0.157847300
# 반복횟수(epoch): 0004 손실함수(loss): 0.158422783
# 반복횟수(epoch): 0004 손실함수(loss): 0.157647505
# 반복횟수(epoch): 0004 손실함수(loss): 0.154950544
# 반복횟수(epoch): 0004 손실함수(loss): 0.155434713
# 반복횟수(epoch): 0004 손실함수(loss): 0.155920208
# 반복횟수(epoch): 0004 손실함수(loss): 0.161332339
# 반복횟수(epoch): 0004 손실함수(loss): 0.156983614
# 반복횟수(epoch): 0004 손실함수(loss): 0.154605374
# 반복횟수(epoch): 0004 손실함수(loss): 0.153261214
# 반복횟수(epoch): 0004 손실함수(loss): 0.155545920
# 반복횟수(epoch): 0004 손실함수(loss): 0.156273216
# 반복횟수(epoch): 0004 손실함수(loss): 0.155724078
# 반복횟수(epoch): 0004 손실함수(loss): 0.156766370
# 반복횟수(epoch): 0004 손실함수(loss): 0.156026348
# 반복횟수(epoch): 0004 손실함수(loss): 0.155096933
# 반복횟수(epoch): 0004 손실함수(loss): 0.156399339
# 반복횟수(epoch): 0004 손실함수(loss): 0.155389413
# 반복횟수(epoch): 0004 손실함수(loss): 0.155413732
# 반복횟수(epoch): 0004 손실함수(loss): 0.152705640
# 반복횟수(epoch): 0004 손실함수(loss): 0.153836012
# 반복횟수(epoch): 0004 손실함수(loss): 0.155947819
# 반복횟수(epoch): 0004 손실함수(loss): 0.154820845
# 반복횟수(epoch): 0004 손실함수(loss): 0.157093853
# 반복횟수(epoch): 0004 손실함수(loss): 0.154358149
# 반복횟수(epoch): 0004 손실함수(loss): 0.157367408
# 반복횟수(epoch): 0004 손실함수(loss): 0.157425895
# 반복횟수(epoch): 0004 손실함수(loss): 0.156345442
# 반복횟수(epoch): 0004 손실함수(loss): 0.153373122
# 반복횟수(epoch): 0004 손실함수(loss): 0.152961850
# 반복횟수(epoch): 0004 손실함수(loss): 0.154549360
# 반복횟수(epoch): 0004 손실함수(loss): 0.152974218
# 반복횟수(epoch): 0004 손실함수(loss): 0.156406358
# 반복횟수(epoch): 0004 손실함수(loss): 0.156211108
# 반복횟수(epoch): 0004 손실함수(loss): 0.153893575
# 반복횟수(epoch): 0004 손실함수(loss): 0.155352384
# 반복횟수(epoch): 0004 손실함수(loss): 0.156480968
# 반복횟수(epoch): 0004 손실함수(loss): 0.155548081
# 반복횟수(epoch): 0004 손실함수(loss): 0.153845906
# 반복횟수(epoch): 0004 손실함수(loss): 0.152452409
# 반복횟수(epoch): 0004 손실함수(loss): 0.153696120
# 반복횟수(epoch): 0004 손실함수(loss): 0.153575778
# 반복횟수(epoch): 0004 손실함수(loss): 0.154016390
# 반복횟수(epoch): 0004 손실함수(loss): 0.155872017
# 반복횟수(epoch): 0004 손실함수(loss): 0.155514255
# 반복횟수(epoch): 0004 손실함수(loss): 0.157357454
# 반복횟수(epoch): 0004 손실함수(loss): 0.154860750
# 반복횟수(epoch): 0004 손실함수(loss): 0.155341223
# 반복횟수(epoch): 0004 손실함수(loss): 0.154842839
# 반복횟수(epoch): 0004 손실함수(loss): 0.155805692
# 반복횟수(epoch): 0004 손실함수(loss): 0.156301856
# 반복횟수(epoch): 0004 손실함수(loss): 0.156967849
# 반복횟수(epoch): 0004 손실함수(loss): 0.154791147
# 반복횟수(epoch): 0004 손실함수(loss): 0.152884901
# 반복횟수(epoch): 0004 손실함수(loss): 0.152910173
# 반복횟수(epoch): 0004 손실함수(loss): 0.151564389
# 반복횟수(epoch): 0004 손실함수(loss): 0.153600201
# 반복횟수(epoch): 0004 손실함수(loss): 0.154867724
# 반복횟수(epoch): 0004 손실함수(loss): 0.153424203
# 반복횟수(epoch): 0004 손실함수(loss): 0.158187836
# 반복횟수(epoch): 0004 손실함수(loss): 0.151847869
# 반복횟수(epoch): 0004 손실함수(loss): 0.152787358
# 반복횟수(epoch): 0004 손실함수(loss): 0.152004361
# 반복횟수(epoch): 0004 손실함수(loss): 0.152210638
# 반복횟수(epoch): 0004 손실함수(loss): 0.152491271
# 반복횟수(epoch): 0004 손실함수(loss): 0.151584432
# 반복횟수(epoch): 0004 손실함수(loss): 0.152486756
# 반복횟수(epoch): 0004 손실함수(loss): 0.150542885
# 반복횟수(epoch): 0004 손실함수(loss): 0.151418835
# 반복횟수(epoch): 0004 손실함수(loss): 0.152745217
# 반복횟수(epoch): 0004 손실함수(loss): 0.152128473
# 반복횟수(epoch): 0004 손실함수(loss): 0.152063176
# 반복횟수(epoch): 0004 손실함수(loss): 0.152864695
# 반복횟수(epoch): 0004 손실함수(loss): 0.152661711
# 반복횟수(epoch): 0004 손실함수(loss): 0.151328817
# 반복횟수(epoch): 0004 손실함수(loss): 0.154779032
# 반복횟수(epoch): 0004 손실함수(loss): 0.152817532
# 반복횟수(epoch): 0004 손실함수(loss): 0.156433225
# 반복횟수(epoch): 0004 손실함수(loss): 0.154226542
# 반복횟수(epoch): 0004 손실함수(loss): 0.155197918
# 반복횟수(epoch): 0004 손실함수(loss): 0.151398167
# 반복횟수(epoch): 0005 손실함수(loss): 0.149936527
# 반복횟수(epoch): 0005 손실함수(loss): 0.151158482
# 반복횟수(epoch): 0005 손실함수(loss): 0.151742116
# 반복횟수(epoch): 0005 손실함수(loss): 0.150725648
# 반복횟수(epoch): 0005 손실함수(loss): 0.150164396
# 반복횟수(epoch): 0005 손실함수(loss): 0.149566352
# 반복횟수(epoch): 0005 손실함수(loss): 0.150120810
# 반복횟수(epoch): 0005 손실함수(loss): 0.149947762
# 반복횟수(epoch): 0005 손실함수(loss): 0.151418447
# 반복횟수(epoch): 0005 손실함수(loss): 0.152292773
# 반복횟수(epoch): 0005 손실함수(loss): 0.151330382
# 반복횟수(epoch): 0005 손실함수(loss): 0.150370702
# 반복횟수(epoch): 0005 손실함수(loss): 0.151810721
# 반복횟수(epoch): 0005 손실함수(loss): 0.150965095
# 반복횟수(epoch): 0005 손실함수(loss): 0.151292950
# 반복횟수(epoch): 0005 손실함수(loss): 0.151743829
# 반복횟수(epoch): 0005 손실함수(loss): 0.151091754
# 반복횟수(epoch): 0005 손실함수(loss): 0.149508715
# 반복횟수(epoch): 0005 손실함수(loss): 0.152154386
# 반복횟수(epoch): 0005 손실함수(loss): 0.149442092
# 반복횟수(epoch): 0005 손실함수(loss): 0.148015738
# 반복횟수(epoch): 0005 손실함수(loss): 0.150271639
# 반복횟수(epoch): 0005 손실함수(loss): 0.150502354
# 반복횟수(epoch): 0005 손실함수(loss): 0.148397475
# 반복횟수(epoch): 0005 손실함수(loss): 0.147877634
# 반복횟수(epoch): 0005 손실함수(loss): 0.149040401
# 반복횟수(epoch): 0005 손실함수(loss): 0.149124354
# 반복횟수(epoch): 0005 손실함수(loss): 0.146745190
# 반복횟수(epoch): 0005 손실함수(loss): 0.148545116
# 반복횟수(epoch): 0005 손실함수(loss): 0.147343591
# 반복횟수(epoch): 0005 손실함수(loss): 0.150741830
# 반복횟수(epoch): 0005 손실함수(loss): 0.147742078
# 반복횟수(epoch): 0005 손실함수(loss): 0.149151847
# 반복횟수(epoch): 0005 손실함수(loss): 0.148263291
# 반복횟수(epoch): 0005 손실함수(loss): 0.147877961
# 반복횟수(epoch): 0005 손실함수(loss): 0.149441093
# 반복횟수(epoch): 0005 손실함수(loss): 0.149068505
# 반복횟수(epoch): 0005 손실함수(loss): 0.148463100
# 반복횟수(epoch): 0005 손실함수(loss): 0.148355395
# 반복횟수(epoch): 0005 손실함수(loss): 0.145862564
# 반복횟수(epoch): 0005 손실함수(loss): 0.150645718
# 반복횟수(epoch): 0005 손실함수(loss): 0.146389440
# 반복횟수(epoch): 0005 손실함수(loss): 0.147688970
# 반복횟수(epoch): 0005 손실함수(loss): 0.147447035
# 반복횟수(epoch): 0005 손실함수(loss): 0.149062485
# 반복횟수(epoch): 0005 손실함수(loss): 0.148058087
# 반복횟수(epoch): 0005 손실함수(loss): 0.147292525
# 반복횟수(epoch): 0005 손실함수(loss): 0.146543130
# 반복횟수(epoch): 0005 손실함수(loss): 0.147757336
# 반복횟수(epoch): 0005 손실함수(loss): 0.149371833
# 반복횟수(epoch): 0005 손실함수(loss): 0.150509000
# 반복횟수(epoch): 0005 손실함수(loss): 0.148276895
# 반복횟수(epoch): 0005 손실함수(loss): 0.146958023
# 반복횟수(epoch): 0005 손실함수(loss): 0.146760866
# 반복횟수(epoch): 0005 손실함수(loss): 0.144263834
# 반복횟수(epoch): 0005 손실함수(loss): 0.143615007
# 반복횟수(epoch): 0005 손실함수(loss): 0.146128848
# 반복횟수(epoch): 0005 손실함수(loss): 0.146137193
# 반복횟수(epoch): 0005 손실함수(loss): 0.148384646
# 반복횟수(epoch): 0005 손실함수(loss): 0.147615507
# 반복횟수(epoch): 0005 손실함수(loss): 0.148038507
# 반복횟수(epoch): 0005 손실함수(loss): 0.147664562
# 반복횟수(epoch): 0005 손실함수(loss): 0.147775710
# 반복횟수(epoch): 0005 손실함수(loss): 0.145588771
# 반복횟수(epoch): 0005 손실함수(loss): 0.147983670
# 반복횟수(epoch): 0005 손실함수(loss): 0.147405937
# 반복횟수(epoch): 0005 손실함수(loss): 0.147529513
# 반복횟수(epoch): 0005 손실함수(loss): 0.146411896
# 반복횟수(epoch): 0005 손실함수(loss): 0.146847889
# 반복횟수(epoch): 0005 손실함수(loss): 0.146210805
# 반복횟수(epoch): 0005 손실함수(loss): 0.147343934
# 반복횟수(epoch): 0005 손실함수(loss): 0.146253511
# 반복횟수(epoch): 0005 손실함수(loss): 0.147744074
# 반복횟수(epoch): 0005 손실함수(loss): 0.146194533
# 반복횟수(epoch): 0005 손실함수(loss): 0.147693992
# 반복횟수(epoch): 0005 손실함수(loss): 0.146031111
# 반복횟수(epoch): 0005 손실함수(loss): 0.147822708
# 반복횟수(epoch): 0005 손실함수(loss): 0.146705031
# 반복횟수(epoch): 0005 손실함수(loss): 0.147106662
# 반복횟수(epoch): 0005 손실함수(loss): 0.147686571
# 반복횟수(epoch): 0005 손실함수(loss): 0.149418041
# 반복횟수(epoch): 0005 손실함수(loss): 0.147788510
# 반복횟수(epoch): 0005 손실함수(loss): 0.146931529
# 반복횟수(epoch): 0005 손실함수(loss): 0.144664496
# 반복횟수(epoch): 0005 손실함수(loss): 0.145569637
# 반복횟수(epoch): 0005 손실함수(loss): 0.142778441
# 반복횟수(epoch): 0005 손실함수(loss): 0.145171165
# 반복횟수(epoch): 0005 손실함수(loss): 0.146527693
# 반복횟수(epoch): 0005 손실함수(loss): 0.147171319
# 반복횟수(epoch): 0005 손실함수(loss): 0.145907670
# 반복횟수(epoch): 0005 손실함수(loss): 0.146170884
# 반복횟수(epoch): 0005 손실함수(loss): 0.145039096
# 반복횟수(epoch): 0005 손실함수(loss): 0.146512046
# 반복횟수(epoch): 0005 손실함수(loss): 0.145353720
# 반복횟수(epoch): 0005 손실함수(loss): 0.145367384
# 반복횟수(epoch): 0005 손실함수(loss): 0.144868091
# 반복횟수(epoch): 0005 손실함수(loss): 0.146208122
# 반복횟수(epoch): 0005 손실함수(loss): 0.144175932
# 반복횟수(epoch): 0005 손실함수(loss): 0.146241546
# 반복횟수(epoch): 0005 손실함수(loss): 0.147437617
# 반복횟수(epoch): 0005 손실함수(loss): 0.147032440
# 반복횟수(epoch): 0005 손실함수(loss): 0.145417899
# 반복횟수(epoch): 0005 손실함수(loss): 0.145891070
# 반복횟수(epoch): 0005 손실함수(loss): 0.148142233
# 반복횟수(epoch): 0005 손실함수(loss): 0.146096498
# 반복횟수(epoch): 0005 손실함수(loss): 0.146779820
# 반복횟수(epoch): 0005 손실함수(loss): 0.145115152
# 반복횟수(epoch): 0005 손실함수(loss): 0.146463439
# 반복횟수(epoch): 0005 손실함수(loss): 0.145693049
# 반복횟수(epoch): 0005 손실함수(loss): 0.146017119
# 반복횟수(epoch): 0005 손실함수(loss): 0.146114036
# 반복횟수(epoch): 0005 손실함수(loss): 0.148073763
# 반복횟수(epoch): 0005 손실함수(loss): 0.145500422
# 반복횟수(epoch): 0005 손실함수(loss): 0.144825429
# 반복횟수(epoch): 0005 손실함수(loss): 0.145315543
# 반복횟수(epoch): 0005 손실함수(loss): 0.146787316
# 반복횟수(epoch): 0005 손실함수(loss): 0.148682013
# 반복횟수(epoch): 0005 손실함수(loss): 0.148409396
# 반복횟수(epoch): 0005 손실함수(loss): 0.146841869
# 반복횟수(epoch): 0005 손실함수(loss): 0.146627098
# 반복횟수(epoch): 0005 손실함수(loss): 0.148262396
# 반복횟수(epoch): 0005 손실함수(loss): 0.147952989
# 반복횟수(epoch): 0005 손실함수(loss): 0.145635411
# 반복횟수(epoch): 0005 손실함수(loss): 0.146249458
# 반복횟수(epoch): 0005 손실함수(loss): 0.146394610
# 반복횟수(epoch): 0005 손실함수(loss): 0.145007953
# 반복횟수(epoch): 0005 손실함수(loss): 0.147489280
# 반복횟수(epoch): 0005 손실함수(loss): 0.144315019
# 반복횟수(epoch): 0005 손실함수(loss): 0.146938309
# 반복횟수(epoch): 0005 손실함수(loss): 0.146797955
# 반복횟수(epoch): 0005 손실함수(loss): 0.146122754
# 반복횟수(epoch): 0005 손실함수(loss): 0.144145519
# 반복횟수(epoch): 0005 손실함수(loss): 0.144516096
# 반복횟수(epoch): 0005 손실함수(loss): 0.144471720
# 반복횟수(epoch): 0005 손실함수(loss): 0.145545691
# 반복횟수(epoch): 0005 손실함수(loss): 0.144199803
# 반복횟수(epoch): 0005 손실함수(loss): 0.145831347
# 반복횟수(epoch): 0005 손실함수(loss): 0.144748673
# 반복횟수(epoch): 0005 손실함수(loss): 0.147373915
# 반복횟수(epoch): 0005 손실함수(loss): 0.145389661
# 반복횟수(epoch): 0005 손실함수(loss): 0.147325575
# 반복횟수(epoch): 0005 손실함수(loss): 0.145087510
# 반복횟수(epoch): 0005 손실함수(loss): 0.148160294
# 반복횟수(epoch): 0005 손실함수(loss): 0.144611984
# 반복횟수(epoch): 0005 손실함수(loss): 0.146342948
# 반복횟수(epoch): 0005 손실함수(loss): 0.145496175
# 반복횟수(epoch): 0005 손실함수(loss): 0.145637199
# 반복횟수(epoch): 0005 손실함수(loss): 0.147535726
# 반복횟수(epoch): 0005 손실함수(loss): 0.144255593
# 반복횟수(epoch): 0005 손실함수(loss): 0.146683872
# 반복횟수(epoch): 0005 손실함수(loss): 0.145192832
# 반복횟수(epoch): 0005 손실함수(loss): 0.146672741
# 반복횟수(epoch): 0005 손실함수(loss): 0.145580575
# 반복횟수(epoch): 0005 손실함수(loss): 0.144796178
# 반복횟수(epoch): 0005 손실함수(loss): 0.145221978
# 반복횟수(epoch): 0005 손실함수(loss): 0.145815536
# 반복횟수(epoch): 0005 손실함수(loss): 0.144478172
# 반복횟수(epoch): 0005 손실함수(loss): 0.145006955
# 반복횟수(epoch): 0005 손실함수(loss): 0.145933449
# 반복횟수(epoch): 0005 손실함수(loss): 0.144401312
# 반복횟수(epoch): 0005 손실함수(loss): 0.146882430
# 반복횟수(epoch): 0005 손실함수(loss): 0.147276059
# 반복횟수(epoch): 0005 손실함수(loss): 0.147473440
# 반복횟수(epoch): 0005 손실함수(loss): 0.146729574
# 반복횟수(epoch): 0005 손실함수(loss): 0.144887075
# 반복횟수(epoch): 0005 손실함수(loss): 0.147228479
# 반복횟수(epoch): 0005 손실함수(loss): 0.147108078
# 반복횟수(epoch): 0005 손실함수(loss): 0.147311524
# 반복횟수(epoch): 0005 손실함수(loss): 0.146354765
# 반복횟수(epoch): 0005 손실함수(loss): 0.144507810
# 반복횟수(epoch): 0005 손실함수(loss): 0.143858001
# 반복횟수(epoch): 0005 손실함수(loss): 0.144120604
# 반복횟수(epoch): 0005 손실함수(loss): 0.144698143
# 반복횟수(epoch): 0005 손실함수(loss): 0.145288676
# 반복횟수(epoch): 0005 손실함수(loss): 0.146549642
# 반복횟수(epoch): 0005 손실함수(loss): 0.147071719
# 반복횟수(epoch): 0005 손실함수(loss): 0.146134734
# 반복횟수(epoch): 0005 손실함수(loss): 0.144163504
# 반복횟수(epoch): 0005 손실함수(loss): 0.145483270
# 반복횟수(epoch): 0005 손실함수(loss): 0.144497916
# 반복횟수(epoch): 0005 손실함수(loss): 0.146698102
# 반복횟수(epoch): 0005 손실함수(loss): 0.145807341
# 반복횟수(epoch): 0005 손실함수(loss): 0.146474957
# 반복횟수(epoch): 0005 손실함수(loss): 0.144013703
# 반복횟수(epoch): 0005 손실함수(loss): 0.145994470
# 반복횟수(epoch): 0005 손실함수(loss): 0.145255297
# 반복횟수(epoch): 0005 손실함수(loss): 0.149096578
# 반복횟수(epoch): 0005 손실함수(loss): 0.145310089
# 반복횟수(epoch): 0005 손실함수(loss): 0.145279124
# 반복횟수(epoch): 0005 손실함수(loss): 0.144819334
# 반복횟수(epoch): 0005 손실함수(loss): 0.144682437
# 반복횟수(epoch): 0005 손실함수(loss): 0.143558234
# 반복횟수(epoch): 0005 손실함수(loss): 0.145254433
# 반복횟수(epoch): 0005 손실함수(loss): 0.145263284
# 반복횟수(epoch): 0005 손실함수(loss): 0.147940263
# 반복횟수(epoch): 0005 손실함수(loss): 0.144726053
# 반복횟수(epoch): 0005 손실함수(loss): 0.146345407
# 반복횟수(epoch): 0005 손실함수(loss): 0.145195559
# 반복횟수(epoch): 0005 손실함수(loss): 0.144627452
# 반복횟수(epoch): 0005 손실함수(loss): 0.145802304
# 반복횟수(epoch): 0005 손실함수(loss): 0.144586384
# 반복횟수(epoch): 0005 손실함수(loss): 0.144659072
# 반복횟수(epoch): 0005 손실함수(loss): 0.144723907
# 반복횟수(epoch): 0005 손실함수(loss): 0.146164820
# 반복횟수(epoch): 0005 손실함수(loss): 0.148351178
# 반복횟수(epoch): 0005 손실함수(loss): 0.147595778
# 반복횟수(epoch): 0005 손실함수(loss): 0.147828370
# 반복횟수(epoch): 0005 손실함수(loss): 0.146378070
# 반복횟수(epoch): 0005 손실함수(loss): 0.143708527
# 반복횟수(epoch): 0005 손실함수(loss): 0.143249959
# 반복횟수(epoch): 0005 손실함수(loss): 0.144210741
# 반복횟수(epoch): 0005 손실함수(loss): 0.146715343
# 반복횟수(epoch): 0005 손실함수(loss): 0.147940770
# 반복횟수(epoch): 0005 손실함수(loss): 0.146843925
# 반복횟수(epoch): 0006 손실함수(loss): 0.145023167
# 반복횟수(epoch): 0006 손실함수(loss): 0.142927796
# 반복횟수(epoch): 0006 손실함수(loss): 0.143766597
# 반복횟수(epoch): 0006 손실함수(loss): 0.144571036
# 반복횟수(epoch): 0006 손실함수(loss): 0.142417669
# 반복횟수(epoch): 0006 손실함수(loss): 0.146062061
# 반복횟수(epoch): 0006 손실함수(loss): 0.143200889
# 반복횟수(epoch): 0006 손실함수(loss): 0.142849743
# 반복횟수(epoch): 0006 손실함수(loss): 0.144514203
# 반복횟수(epoch): 0006 손실함수(loss): 0.143982023
# 반복횟수(epoch): 0006 손실함수(loss): 0.143206492
# 반복횟수(epoch): 0006 손실함수(loss): 0.142867565
# 반복횟수(epoch): 0006 손실함수(loss): 0.144028515
# 반복횟수(epoch): 0006 손실함수(loss): 0.143003464
# 반복횟수(epoch): 0006 손실함수(loss): 0.142790779
# 반복횟수(epoch): 0006 손실함수(loss): 0.143253013
# 반복횟수(epoch): 0006 손실함수(loss): 0.143359199
# 반복횟수(epoch): 0006 손실함수(loss): 0.145334080
# 반복횟수(epoch): 0006 손실함수(loss): 0.144724131
# 반복횟수(epoch): 0006 손실함수(loss): 0.145466551
# 반복횟수(epoch): 0006 손실함수(loss): 0.142729342
# 반복횟수(epoch): 0006 손실함수(loss): 0.143461019
# 반복횟수(epoch): 0006 손실함수(loss): 0.142514139
# 반복횟수(epoch): 0006 손실함수(loss): 0.144036740
# 반복횟수(epoch): 0006 손실함수(loss): 0.144793496
# 반복횟수(epoch): 0006 손실함수(loss): 0.143280998
# 반복횟수(epoch): 0006 손실함수(loss): 0.141453072
# 반복횟수(epoch): 0006 손실함수(loss): 0.142129853
# 반복횟수(epoch): 0006 손실함수(loss): 0.140869126
# 반복횟수(epoch): 0006 손실함수(loss): 0.143078357
# 반복횟수(epoch): 0006 손실함수(loss): 0.141529992
# 반복횟수(epoch): 0006 손실함수(loss): 0.142884120
# 반복횟수(epoch): 0006 손실함수(loss): 0.141410366
# 반복횟수(epoch): 0006 손실함수(loss): 0.140001670
# 반복횟수(epoch): 0006 손실함수(loss): 0.141307175
# 반복횟수(epoch): 0006 손실함수(loss): 0.141328350
# 반복횟수(epoch): 0006 손실함수(loss): 0.142469972
# 반복횟수(epoch): 0006 손실함수(loss): 0.141454905
# 반복횟수(epoch): 0006 손실함수(loss): 0.141269445
# 반복횟수(epoch): 0006 손실함수(loss): 0.143109769
# 반복횟수(epoch): 0006 손실함수(loss): 0.141881704
# 반복횟수(epoch): 0006 손실함수(loss): 0.141023308
# 반복횟수(epoch): 0006 손실함수(loss): 0.140872940
# 반복횟수(epoch): 0006 손실함수(loss): 0.141501695
# 반복횟수(epoch): 0006 손실함수(loss): 0.141190782
# 반복횟수(epoch): 0006 손실함수(loss): 0.139439315
# 반복횟수(epoch): 0006 손실함수(loss): 0.140610099
# 반복횟수(epoch): 0006 손실함수(loss): 0.140709549
# 반복횟수(epoch): 0006 손실함수(loss): 0.141052768
# 반복횟수(epoch): 0006 손실함수(loss): 0.141138598
# 반복횟수(epoch): 0006 손실함수(loss): 0.140384898
# 반복횟수(epoch): 0006 손실함수(loss): 0.142734021
# 반복횟수(epoch): 0006 손실함수(loss): 0.140915394
# 반복횟수(epoch): 0006 손실함수(loss): 0.143943787
# 반복횟수(epoch): 0006 손실함수(loss): 0.139289007
# 반복횟수(epoch): 0006 손실함수(loss): 0.141176596
# 반복횟수(epoch): 0006 손실함수(loss): 0.141136929
# 반복횟수(epoch): 0006 손실함수(loss): 0.141388938
# 반복횟수(epoch): 0006 손실함수(loss): 0.139832377
# 반복횟수(epoch): 0006 손실함수(loss): 0.139095411
# 반복횟수(epoch): 0006 손실함수(loss): 0.141118035
# 반복횟수(epoch): 0006 손실함수(loss): 0.141031832
# 반복횟수(epoch): 0006 손실함수(loss): 0.142015457
# 반복횟수(epoch): 0006 손실함수(loss): 0.143689275
# 반복횟수(epoch): 0006 손실함수(loss): 0.140382454
# 반복횟수(epoch): 0006 손실함수(loss): 0.139171049
# 반복횟수(epoch): 0006 손실함수(loss): 0.141813532
# 반복횟수(epoch): 0006 손실함수(loss): 0.142085180
# 반복횟수(epoch): 0006 손실함수(loss): 0.141693980
# 반복횟수(epoch): 0006 손실함수(loss): 0.141754210
# 반복횟수(epoch): 0006 손실함수(loss): 0.140930995
# 반복횟수(epoch): 0006 손실함수(loss): 0.139560759
# ...
# 반복횟수(epoch): 0019 손실함수(loss): 0.116888367
# 반복횟수(epoch): 0019 손실함수(loss): 0.117484190
# 반복횟수(epoch): 0019 손실함수(loss): 0.116047375
# 반복횟수(epoch): 0019 손실함수(loss): 0.115157105
# 반복횟수(epoch): 0019 손실함수(loss): 0.114615738
# 반복횟수(epoch): 0019 손실함수(loss): 0.114007175
# 반복횟수(epoch): 0019 손실함수(loss): 0.116137795
# 반복횟수(epoch): 0019 손실함수(loss): 0.115690507
# 반복횟수(epoch): 0019 손실함수(loss): 0.117228039
# 반복횟수(epoch): 0019 손실함수(loss): 0.116107374
# 반복횟수(epoch): 0019 손실함수(loss): 0.115801618
# 반복횟수(epoch): 0019 손실함수(loss): 0.116223268
# 반복횟수(epoch): 0019 손실함수(loss): 0.115895756
# 반복횟수(epoch): 0019 손실함수(loss): 0.116416074
# 반복횟수(epoch): 0019 손실함수(loss): 0.116251692
# 반복횟수(epoch): 0019 손실함수(loss): 0.115724117
# 반복횟수(epoch): 0019 손실함수(loss): 0.114822038
# 반복횟수(epoch): 0019 손실함수(loss): 0.115567207
# 반복횟수(epoch): 0019 손실함수(loss): 0.116003811
# 반복횟수(epoch): 0019 손실함수(loss): 0.116621993
# 반복횟수(epoch): 0019 손실함수(loss): 0.117689736
# 반복횟수(epoch): 0019 손실함수(loss): 0.119737506
# 반복횟수(epoch): 0019 손실함수(loss): 0.117873348
# 반복횟수(epoch): 0019 손실함수(loss): 0.117530182
# 반복횟수(epoch): 0019 손실함수(loss): 0.117633544
# 반복횟수(epoch): 0019 손실함수(loss): 0.115060709
# 반복횟수(epoch): 0019 손실함수(loss): 0.117179304
# 반복횟수(epoch): 0019 손실함수(loss): 0.117722489
# 반복횟수(epoch): 0019 손실함수(loss): 0.116567418
# 반복횟수(epoch): 0019 손실함수(loss): 0.114851624
# 반복횟수(epoch): 0019 손실함수(loss): 0.116828494
# 반복횟수(epoch): 0019 손실함수(loss): 0.116921932
# 반복횟수(epoch): 0019 손실함수(loss): 0.117050990
# 반복횟수(epoch): 0019 손실함수(loss): 0.116751172
# 반복횟수(epoch): 0019 손실함수(loss): 0.115927733
# 반복횟수(epoch): 0019 손실함수(loss): 0.116893582
# 반복횟수(epoch): 0019 손실함수(loss): 0.116787374
# 반복횟수(epoch): 0019 손실함수(loss): 0.115625955
# 반복횟수(epoch): 0019 손실함수(loss): 0.115560725
# 반복횟수(epoch): 0019 손실함수(loss): 0.116283864
# 반복횟수(epoch): 0019 손실함수(loss): 0.115327522
# 반복횟수(epoch): 0019 손실함수(loss): 0.114963859
# 반복횟수(epoch): 0019 손실함수(loss): 0.117085800
# 반복횟수(epoch): 0019 손실함수(loss): 0.117301591
# 반복횟수(epoch): 0019 손실함수(loss): 0.115924969
# 반복횟수(epoch): 0019 손실함수(loss): 0.115310006
# 반복횟수(epoch): 0019 손실함수(loss): 0.116126858
# 반복횟수(epoch): 0019 손실함수(loss): 0.116568841
# 반복횟수(epoch): 0019 손실함수(loss): 0.116310745
# 반복횟수(epoch): 0019 손실함수(loss): 0.117400579
# 반복횟수(epoch): 0019 손실함수(loss): 0.116858266
# 반복횟수(epoch): 0019 손실함수(loss): 0.117379993
# 반복횟수(epoch): 0019 손실함수(loss): 0.118287221
# 반복횟수(epoch): 0019 손실함수(loss): 0.116442457
# 반복횟수(epoch): 0019 손실함수(loss): 0.115119800
# 반복횟수(epoch): 0019 손실함수(loss): 0.115824901
# 반복횟수(epoch): 0019 손실함수(loss): 0.115271129
# 반복횟수(epoch): 0019 손실함수(loss): 0.116058916
# 반복횟수(epoch): 0019 손실함수(loss): 0.113705866
# 반복횟수(epoch): 0019 손실함수(loss): 0.116160959
# 반복횟수(epoch): 0019 손실함수(loss): 0.115878999
# 반복횟수(epoch): 0019 손실함수(loss): 0.117214926
# 반복횟수(epoch): 0019 손실함수(loss): 0.118013769
# 반복횟수(epoch): 0019 손실함수(loss): 0.117887691
# 반복횟수(epoch): 0019 손실함수(loss): 0.114124022
# 반복횟수(epoch): 0019 손실함수(loss): 0.113605395
# 반복횟수(epoch): 0019 손실함수(loss): 0.113466613
# 반복횟수(epoch): 0019 손실함수(loss): 0.116227828
# 반복횟수(epoch): 0019 손실함수(loss): 0.114819199
# 반복횟수(epoch): 0019 손실함수(loss): 0.117120996
# 반복횟수(epoch): 0019 손실함수(loss): 0.116326176
# 반복횟수(epoch): 0019 손실함수(loss): 0.117438689
# 반복횟수(epoch): 0019 손실함수(loss): 0.115345351
# 반복횟수(epoch): 0019 손실함수(loss): 0.115437880
# 반복횟수(epoch): 0019 손실함수(loss): 0.115753166
# 반복횟수(epoch): 0019 손실함수(loss): 0.116773807
# 반복횟수(epoch): 0019 손실함수(loss): 0.114721008
# 반복횟수(epoch): 0019 손실함수(loss): 0.115561701
# 반복횟수(epoch): 0019 손실함수(loss): 0.115630440
# 반복횟수(epoch): 0019 손실함수(loss): 0.114761613
# 반복횟수(epoch): 0019 손실함수(loss): 0.115190327
# 반복횟수(epoch): 0019 손실함수(loss): 0.115284473
# 반복횟수(epoch): 0019 손실함수(loss): 0.113564916
# 반복횟수(epoch): 0019 손실함수(loss): 0.114755981
# 반복횟수(epoch): 0019 손실함수(loss): 0.115525998
# 반복횟수(epoch): 0019 손실함수(loss): 0.115930311
# 반복횟수(epoch): 0019 손실함수(loss): 0.114909209
# 반복횟수(epoch): 0019 손실함수(loss): 0.114696734
# 반복횟수(epoch): 0019 손실함수(loss): 0.112989083
# 반복횟수(epoch): 0019 손실함수(loss): 0.116259299
# 반복횟수(epoch): 0019 손실함수(loss): 0.116031669
# 반복횟수(epoch): 0019 손실함수(loss): 0.116734780
# 반복횟수(epoch): 0019 손실함수(loss): 0.114281245
# 반복횟수(epoch): 0019 손실함수(loss): 0.115452513
# 반복횟수(epoch): 0019 손실함수(loss): 0.113918044
# 반복횟수(epoch): 0019 손실함수(loss): 0.113816142
# 반복횟수(epoch): 0019 손실함수(loss): 0.115721472
# 반복횟수(epoch): 0019 손실함수(loss): 0.114530154
# 반복횟수(epoch): 0019 손실함수(loss): 0.115517206
# 반복횟수(epoch): 0019 손실함수(loss): 0.116921641
# 반복횟수(epoch): 0019 손실함수(loss): 0.116355903
# 반복횟수(epoch): 0019 손실함수(loss): 0.117163777
# 반복횟수(epoch): 0019 손실함수(loss): 0.115548924
# 반복횟수(epoch): 0019 손실함수(loss): 0.114049174
# 반복횟수(epoch): 0019 손실함수(loss): 0.113858804
# 반복횟수(epoch): 0019 손실함수(loss): 0.114576362
# 반복횟수(epoch): 0019 손실함수(loss): 0.113604330
# 반복횟수(epoch): 0019 손실함수(loss): 0.115625508
# 반복횟수(epoch): 0019 손실함수(loss): 0.114554912
# 반복횟수(epoch): 0019 손실함수(loss): 0.113754682
# 반복횟수(epoch): 0019 손실함수(loss): 0.113454208
# 반복횟수(epoch): 0019 손실함수(loss): 0.112551026
# 반복횟수(epoch): 0019 손실함수(loss): 0.115633160
# 반복횟수(epoch): 0019 손실함수(loss): 0.116782799
# 반복횟수(epoch): 0019 손실함수(loss): 0.115381882
# 반복횟수(epoch): 0019 손실함수(loss): 0.115917005
# 반복횟수(epoch): 0019 손실함수(loss): 0.114972405
# 반복횟수(epoch): 0019 손실함수(loss): 0.114279740
# 반복횟수(epoch): 0019 손실함수(loss): 0.115627281
# 반복횟수(epoch): 0019 손실함수(loss): 0.116039120
# 반복횟수(epoch): 0019 손실함수(loss): 0.114860468
# 반복횟수(epoch): 0019 손실함수(loss): 0.114656933
# 반복횟수(epoch): 0019 손실함수(loss): 0.113381773
# 반복횟수(epoch): 0019 손실함수(loss): 0.111529551
# 반복횟수(epoch): 0019 손실함수(loss): 0.113699161
# 반복횟수(epoch): 0019 손실함수(loss): 0.112792365
# 반복횟수(epoch): 0019 손실함수(loss): 0.113689482
# 반복횟수(epoch): 0019 손실함수(loss): 0.114422217
# 반복횟수(epoch): 0019 손실함수(loss): 0.115144700
# 반복횟수(epoch): 0019 손실함수(loss): 0.114164859
# 반복횟수(epoch): 0019 손실함수(loss): 0.112212017
# 반복횟수(epoch): 0019 손실함수(loss): 0.113083616
# 반복횟수(epoch): 0019 손실함수(loss): 0.115536712
# 반복횟수(epoch): 0019 손실함수(loss): 0.113888718
# 반복횟수(epoch): 0019 손실함수(loss): 0.114395358
# 반복횟수(epoch): 0019 손실함수(loss): 0.113943294
# 반복횟수(epoch): 0019 손실함수(loss): 0.114235297
# 반복횟수(epoch): 0019 손실함수(loss): 0.115459718
# 반복횟수(epoch): 0019 손실함수(loss): 0.113171041
# 반복횟수(epoch): 0019 손실함수(loss): 0.115657404
# 반복횟수(epoch): 0019 손실함수(loss): 0.115608819
# 반복횟수(epoch): 0019 손실함수(loss): 0.114533268
# 반복횟수(epoch): 0019 손실함수(loss): 0.116826512
# 반복횟수(epoch): 0019 손실함수(loss): 0.116851769
# 반복횟수(epoch): 0019 손실함수(loss): 0.115686439
# 반복횟수(epoch): 0019 손실함수(loss): 0.112845048
# 반복횟수(epoch): 0019 손실함수(loss): 0.115221471
# 반복횟수(epoch): 0019 손실함수(loss): 0.113404952
# 반복횟수(epoch): 0019 손실함수(loss): 0.114775665
# 반복횟수(epoch): 0019 손실함수(loss): 0.114158608
# 반복횟수(epoch): 0019 손실함수(loss): 0.115060553
# 반복횟수(epoch): 0019 손실함수(loss): 0.114147559
# 반복횟수(epoch): 0019 손실함수(loss): 0.113440797
# 반복횟수(epoch): 0019 손실함수(loss): 0.113946624
# 반복횟수(epoch): 0019 손실함수(loss): 0.112161562
# 반복횟수(epoch): 0019 손실함수(loss): 0.112570584
# 반복횟수(epoch): 0019 손실함수(loss): 0.114650346
# 반복횟수(epoch): 0019 손실함수(loss): 0.111405171
# 반복횟수(epoch): 0019 손실함수(loss): 0.112241067
# 반복횟수(epoch): 0019 손실함수(loss): 0.110816658
# 반복횟수(epoch): 0019 손실함수(loss): 0.112245150
# 반복횟수(epoch): 0020 손실함수(loss): 0.112286031
# 반복횟수(epoch): 0020 손실함수(loss): 0.112963796
# 반복횟수(epoch): 0020 손실함수(loss): 0.114521801
# 반복횟수(epoch): 0020 손실함수(loss): 0.114990816
# 반복횟수(epoch): 0020 손실함수(loss): 0.116380982
# 반복횟수(epoch): 0020 손실함수(loss): 0.114598177
# 반복횟수(epoch): 0020 손실함수(loss): 0.113400020
# 반복횟수(epoch): 0020 손실함수(loss): 0.113282830
# 반복횟수(epoch): 0020 손실함수(loss): 0.112940595
# 반복횟수(epoch): 0020 손실함수(loss): 0.112445615
# 반복횟수(epoch): 0020 손실함수(loss): 0.114302322
# 반복횟수(epoch): 0020 손실함수(loss): 0.114163205
# 반복횟수(epoch): 0020 손실함수(loss): 0.114881732
# 반복횟수(epoch): 0020 손실함수(loss): 0.114070259
# 반복횟수(epoch): 0020 손실함수(loss): 0.112942323
# 반복횟수(epoch): 0020 손실함수(loss): 0.112393059
# 반복횟수(epoch): 0020 손실함수(loss): 0.113363013
# 반복횟수(epoch): 0020 손실함수(loss): 0.112034351
# 반복횟수(epoch): 0020 손실함수(loss): 0.113896646
# 반복횟수(epoch): 0020 손실함수(loss): 0.113883331
# 반복횟수(epoch): 0020 손실함수(loss): 0.115638129
# 반복횟수(epoch): 0020 손실함수(loss): 0.112675242
# 반복횟수(epoch): 0020 손실함수(loss): 0.112944275
# 반복횟수(epoch): 0020 손실함수(loss): 0.112717368
# 반복횟수(epoch): 0020 손실함수(loss): 0.116607122
# 반복횟수(epoch): 0020 손실함수(loss): 0.115658350
# 반복횟수(epoch): 0020 손실함수(loss): 0.114658535
# 반복횟수(epoch): 0020 손실함수(loss): 0.114255145
# 반복횟수(epoch): 0020 손실함수(loss): 0.114018977
# 반복횟수(epoch): 0020 손실함수(loss): 0.115288451
# 반복횟수(epoch): 0020 손실함수(loss): 0.113607056
# 반복횟수(epoch): 0020 손실함수(loss): 0.112020627
# 반복횟수(epoch): 0020 손실함수(loss): 0.113583602
# 반복횟수(epoch): 0020 손실함수(loss): 0.113801837
# 반복횟수(epoch): 0020 손실함수(loss): 0.115018934
# 반복횟수(epoch): 0020 손실함수(loss): 0.114532702
# 반복횟수(epoch): 0020 손실함수(loss): 0.113552794
# 반복횟수(epoch): 0020 손실함수(loss): 0.112351775
# 반복횟수(epoch): 0020 손실함수(loss): 0.112783998
# 반복횟수(epoch): 0020 손실함수(loss): 0.112731040
# 반복횟수(epoch): 0020 손실함수(loss): 0.111990519
# 반복횟수(epoch): 0020 손실함수(loss): 0.112671539
# 반복횟수(epoch): 0020 손실함수(loss): 0.114119679
# 반복횟수(epoch): 0020 손실함수(loss): 0.113498963
# 반복횟수(epoch): 0020 손실함수(loss): 0.114505962
# 반복횟수(epoch): 0020 손실함수(loss): 0.113747440
# 반복횟수(epoch): 0020 손실함수(loss): 0.114336386
# 반복횟수(epoch): 0020 손실함수(loss): 0.113596283
# 반복횟수(epoch): 0020 손실함수(loss): 0.111042395
# 반복횟수(epoch): 0020 손실함수(loss): 0.111971594
# 반복횟수(epoch): 0020 손실함수(loss): 0.112370260
# 반복횟수(epoch): 0020 손실함수(loss): 0.113585375
# 반복횟수(epoch): 0020 손실함수(loss): 0.115108140
# 반복횟수(epoch): 0020 손실함수(loss): 0.113597833
# 반복횟수(epoch): 0020 손실함수(loss): 0.112461686
# 반복횟수(epoch): 0020 손실함수(loss): 0.110534579
# 반복횟수(epoch): 0020 손실함수(loss): 0.111039042
# 반복횟수(epoch): 0020 손실함수(loss): 0.113060758
# 반복횟수(epoch): 0020 손실함수(loss): 0.111992262
# 반복횟수(epoch): 0020 손실함수(loss): 0.113408267
# 반복횟수(epoch): 0020 손실함수(loss): 0.114930578
# 반복횟수(epoch): 0020 손실함수(loss): 0.114578635
# 반복횟수(epoch): 0020 손실함수(loss): 0.112748772
# 반복횟수(epoch): 0020 손실함수(loss): 0.114913024
# 반복횟수(epoch): 0020 손실함수(loss): 0.114333019
# 반복횟수(epoch): 0020 손실함수(loss): 0.115234919
# 반복횟수(epoch): 0020 손실함수(loss): 0.114215367
# 반복횟수(epoch): 0020 손실함수(loss): 0.115535550
# 반복횟수(epoch): 0020 손실함수(loss): 0.112037539
# 반복횟수(epoch): 0020 손실함수(loss): 0.114359893
# 반복횟수(epoch): 0020 손실함수(loss): 0.113099515
# 반복횟수(epoch): 0020 손실함수(loss): 0.116009831
# 반복횟수(epoch): 0020 손실함수(loss): 0.113075234
# 반복횟수(epoch): 0020 손실함수(loss): 0.112992965
# 반복횟수(epoch): 0020 손실함수(loss): 0.111797526
# 반복횟수(epoch): 0020 손실함수(loss): 0.111095555
# 반복횟수(epoch): 0020 손실함수(loss): 0.113041624
# 반복횟수(epoch): 0020 손실함수(loss): 0.114712648
# 반복횟수(epoch): 0020 손실함수(loss): 0.115686089
# 반복횟수(epoch): 0020 손실함수(loss): 0.114001676
# 반복횟수(epoch): 0020 손실함수(loss): 0.112653188
# 반복횟수(epoch): 0020 손실함수(loss): 0.112414338
# 반복횟수(epoch): 0020 손실함수(loss): 0.113074787
# 반복횟수(epoch): 0020 손실함수(loss): 0.114308104
# 반복횟수(epoch): 0020 손실함수(loss): 0.114721075
# 반복횟수(epoch): 0020 손실함수(loss): 0.115081400
# 반복횟수(epoch): 0020 손실함수(loss): 0.115286052
# 반복횟수(epoch): 0020 손실함수(loss): 0.113771409
# 반복횟수(epoch): 0020 손실함수(loss): 0.113801301
# 반복횟수(epoch): 0020 손실함수(loss): 0.113542460
# 반복횟수(epoch): 0020 손실함수(loss): 0.113158010
# 반복횟수(epoch): 0020 손실함수(loss): 0.112336405
# 반복횟수(epoch): 0020 손실함수(loss): 0.112607256
# 반복횟수(epoch): 0020 손실함수(loss): 0.112822317
# 반복횟수(epoch): 0020 손실함수(loss): 0.113233894
# 반복횟수(epoch): 0020 손실함수(loss): 0.112024188
# 반복횟수(epoch): 0020 손실함수(loss): 0.111793339
# 반복횟수(epoch): 0020 손실함수(loss): 0.111951284
# 반복횟수(epoch): 0020 손실함수(loss): 0.111738801
# 반복횟수(epoch): 0020 손실함수(loss): 0.114753172
# 반복횟수(epoch): 0020 손실함수(loss): 0.114659011
# 반복횟수(epoch): 0020 손실함수(loss): 0.115615472
# 반복횟수(epoch): 0020 손실함수(loss): 0.114748597
# 반복횟수(epoch): 0020 손실함수(loss): 0.114019364
# 반복횟수(epoch): 0020 손실함수(loss): 0.112803832
# 반복횟수(epoch): 0020 손실함수(loss): 0.115704849
# 반복횟수(epoch): 0020 손실함수(loss): 0.114179842
# 반복횟수(epoch): 0020 손실함수(loss): 0.113725446
# 반복횟수(epoch): 0020 손실함수(loss): 0.112952776
# 반복횟수(epoch): 0020 손실함수(loss): 0.111471020
# 반복횟수(epoch): 0020 손실함수(loss): 0.112216718
# 반복횟수(epoch): 0020 손실함수(loss): 0.113609366
# 반복횟수(epoch): 0020 손실함수(loss): 0.111419491
# 반복횟수(epoch): 0020 손실함수(loss): 0.113020703
# 반복횟수(epoch): 0020 손실함수(loss): 0.113276541
# 반복횟수(epoch): 0020 손실함수(loss): 0.115010768
# 반복횟수(epoch): 0020 손실함수(loss): 0.113049991
# 반복횟수(epoch): 0020 손실함수(loss): 0.116070844
# 반복횟수(epoch): 0020 손실함수(loss): 0.113325350
# 반복횟수(epoch): 0020 손실함수(loss): 0.112714030
# 반복횟수(epoch): 0020 손실함수(loss): 0.111759312
# 반복횟수(epoch): 0020 손실함수(loss): 0.114746578
# 반복횟수(epoch): 0020 손실함수(loss): 0.112912998
# 반복횟수(epoch): 0020 손실함수(loss): 0.112365142
# 반복횟수(epoch): 0020 손실함수(loss): 0.112251960
# 반복횟수(epoch): 0020 손실함수(loss): 0.112973034
# 반복횟수(epoch): 0020 손실함수(loss): 0.112944178
# 반복횟수(epoch): 0020 손실함수(loss): 0.114883073
# 반복횟수(epoch): 0020 손실함수(loss): 0.110876687
# 반복횟수(epoch): 0020 손실함수(loss): 0.112129211
# 반복횟수(epoch): 0020 손실함수(loss): 0.113740824
# 반복횟수(epoch): 0020 손실함수(loss): 0.113512665
# 반복횟수(epoch): 0020 손실함수(loss): 0.113583408
# 반복횟수(epoch): 0020 손실함수(loss): 0.112584539
# 반복횟수(epoch): 0020 손실함수(loss): 0.112519845
# 반복횟수(epoch): 0020 손실함수(loss): 0.114755653
# 반복횟수(epoch): 0020 손실함수(loss): 0.114406489
# 반복횟수(epoch): 0020 손실함수(loss): 0.115846932
# 반복횟수(epoch): 0020 손실함수(loss): 0.113083906
# 반복횟수(epoch): 0020 손실함수(loss): 0.114878327
# 반복횟수(epoch): 0020 손실함수(loss): 0.114423901
# 반복횟수(epoch): 0020 손실함수(loss): 0.112600163
# 반복횟수(epoch): 0020 손실함수(loss): 0.111308798
# 반복횟수(epoch): 0020 손실함수(loss): 0.112444781
# 반복횟수(epoch): 0020 손실함수(loss): 0.111926705
# 반복횟수(epoch): 0020 손실함수(loss): 0.112429440
# 반복횟수(epoch): 0020 손실함수(loss): 0.113648884
# 반복횟수(epoch): 0020 손실함수(loss): 0.115491286
# 반복횟수(epoch): 0020 손실함수(loss): 0.113246493
# 반복횟수(epoch): 0020 손실함수(loss): 0.112634309
# 반복횟수(epoch): 0020 손실함수(loss): 0.113217771
# 반복횟수(epoch): 0020 손실함수(loss): 0.113927864
# 반복횟수(epoch): 0020 손실함수(loss): 0.113132790
# 반복횟수(epoch): 0020 손실함수(loss): 0.113910519
# 반복횟수(epoch): 0020 손실함수(loss): 0.114089333
# 반복횟수(epoch): 0020 손실함수(loss): 0.111682519
# 반복횟수(epoch): 0020 손실함수(loss): 0.112649336
# 반복횟수(epoch): 0020 손실함수(loss): 0.112057649
# 반복횟수(epoch): 0020 손실함수(loss): 0.113820717
# 반복횟수(epoch): 0020 손실함수(loss): 0.114402458
# 반복횟수(epoch): 0020 손실함수(loss): 0.112747930
# 반복횟수(epoch): 0020 손실함수(loss): 0.113779768
# 반복횟수(epoch): 0020 손실함수(loss): 0.113868341
# 반복횟수(epoch): 0020 손실함수(loss): 0.113505051
# 반복횟수(epoch): 0020 손실함수(loss): 0.112273715
# 반복횟수(epoch): 0020 손실함수(loss): 0.111434117
# 반복횟수(epoch): 0020 손실함수(loss): 0.111988962
# 반복횟수(epoch): 0020 손실함수(loss): 0.110662073
# 반복횟수(epoch): 0020 손실함수(loss): 0.111573532
# 반복횟수(epoch): 0020 손실함수(loss): 0.112615384
# 반복횟수(epoch): 0020 손실함수(loss): 0.114318788
# 반복횟수(epoch): 0020 손실함수(loss): 0.115754634
# 반복횟수(epoch): 0020 손실함수(loss): 0.111877061
# 반복횟수(epoch): 0020 손실함수(loss): 0.114753015
# 반복횟수(epoch): 0020 손실함수(loss): 0.113444768
# 반복횟수(epoch): 0020 손실함수(loss): 0.113917828
# 반복횟수(epoch): 0020 손실함수(loss): 0.112797014
# 반복횟수(epoch): 0020 손실함수(loss): 0.112907641
# 반복횟수(epoch): 0020 손실함수(loss): 0.113086097
# 반복횟수(epoch): 0020 손실함수(loss): 0.115312092
# 반복횟수(epoch): 0020 손실함수(loss): 0.113194212
# 반복횟수(epoch): 0020 손실함수(loss): 0.115173519
# 반복횟수(epoch): 0020 손실함수(loss): 0.113510229
# 반복횟수(epoch): 0020 손실함수(loss): 0.113677524
# 반복횟수(epoch): 0020 손실함수(loss): 0.115090646
# 반복횟수(epoch): 0020 손실함수(loss): 0.115027107
# 반복횟수(epoch): 0020 손실함수(loss): 0.112341687
# 반복횟수(epoch): 0020 손실함수(loss): 0.113030203
# 반복횟수(epoch): 0020 손실함수(loss): 0.112553850
# 반복횟수(epoch): 0020 손실함수(loss): 0.112760469
# 반복횟수(epoch): 0020 손실함수(loss): 0.112014636
# 반복횟수(epoch): 0020 손실함수(loss): 0.112456203
# 반복횟수(epoch): 0020 손실함수(loss): 0.112215683
# 반복횟수(epoch): 0020 손실함수(loss): 0.111637771
# 반복횟수(epoch): 0020 손실함수(loss): 0.112784363
# 반복횟수(epoch): 0020 손실함수(loss): 0.113909841
# 반복횟수(epoch): 0020 손실함수(loss): 0.112568058
# 반복횟수(epoch): 0020 손실함수(loss): 0.114070423
# 반복횟수(epoch): 0020 손실함수(loss): 0.114311352
# 반복횟수(epoch): 0020 손실함수(loss): 0.115206972
# 반복횟수(epoch): 0020 손실함수(loss): 0.112841785
# 반복횟수(epoch): 0020 손실함수(loss): 0.115098752
# 반복횟수(epoch): 0020 손실함수(loss): 0.113310345
# 반복횟수(epoch): 0020 손실함수(loss): 0.115346968
# 반복횟수(epoch): 0020 손실함수(loss): 0.112750024
# 반복횟수(epoch): 0020 손실함수(loss): 0.114679687
# 반복횟수(epoch): 0020 손실함수(loss): 0.112161152
# 반복횟수(epoch): 0020 손실함수(loss): 0.112737186
# 반복횟수(epoch): 0020 손실함수(loss): 0.111802459
# 반복횟수(epoch): 0020 손실함수(loss): 0.112920821
# 반복횟수(epoch): 0020 손실함수(loss): 0.113460802
# 반복횟수(epoch): 0020 손실함수(loss): 0.114080489
# 반복횟수(epoch): 0020 손실함수(loss): 0.111029468
# 반복횟수(epoch): 0020 손실함수(loss): 0.113965191
# 최적화 완료
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
